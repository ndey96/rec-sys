# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import pandas as pd
from tqdm import tqdm
import numpy as np
import time

username = 'ndey96'
scope = 'user-top-read'
token = util.prompt_for_user_token(username,
                                   scope,
                                   client_id='02c386b9bcfb43248ad7011c576c1e3f',
                                   client_secret='f2406ab918d349689325d2f6916aa656',
                                   redirect_uri='http://localhost:8888')
sp = spotipy.Spotify(auth=token)
sp.trace = False
tracks = sp.current_user_top_tracks(time_range='medium_term', limit=50)
for i, item in enumerate(tracks['items']):
    print(i, item['name'], '//', item['artists'][0]['name'])
# Out:
# 0 Five Hours // Deorro
# 1 Wesley's Theory // Kendrick Lamar
# 2 Come Down // Anderson .Paak
# 3 Sultans Of Swing // Dire Straits
# 4 Backseat Freestyle // Kendrick Lamar
# 5 i // Kendrick Lamar
# 6 Cold Little Heart - Radio Edit // Michael Kiwanuka
# 7 The Bottle // Gill Scott
# 8 Footsteps in the Dark, Pts. 1 & 2 // The Isley Brothers
# 9 Put Me Thru // Anderson .Paak
# 10 Feasting on the Flowers // Red Hot Chili Peppers
# 11 Sweet Emotion - Montmartre Remix // The Kooks
# 12 Dangerous - Sebu Remix // Big Data
# 13 Helicopter // Bloc Party
# 14 All Night (feat. Knox Fortune) // Chance the Rapper
# 15 School // Calvin Harris
# 16 I Love My Friends // Foster The People
# 17 Kalahari // Take/Five
# 18 IV. Sweatpants // Childish Gambino
# 19 Redbone // Childish Gambino
# 20 Sucker for Love // Cherub
# 21 King Kunta // Kendrick Lamar
# 22 Dear Neighbor (feat. Jenni Potts) - Pham Remix // Flapo
# 23 The City // Anderson .Paak
# 24 Canned Heat // Jamiroquai
# 25 Learn to Trust // Bad Suns
# 26 The Less I Know The Better // Tame Impala
# 27 i // Kendrick Lamar
# 28 ATM // J. Cole
# 29 Goodbye Angels // Red Hot Chili Peppers
# 30 City Of Stars - From "La La Land" Soundtrack/Pier // Ryan Gosling
# 31 Let It Happen // Tame Impala
# 32 m.A.A.d city // Kendrick Lamar
# 33 Hip Hop // Mos Def
# 34 Doncamatic - feat. Daley // Gorillaz
# 35 Disco Inferno - Single Edit // The Trammps
# 36 Can't Hold Us - feat. Ray Dalton // Macklemore & Ryan Lewis
# 37 Trouble // Cage The Elephant
# 38 Dark Necessities // Red Hot Chili Peppers
# 39 Snow (Hey Oh) // Red Hot Chili Peppers
# 40 Black Panda // Koi Child
# 41 Rich (feat. Anndreyah Vargas) - Radio Edit // Cosmo Sheldrake
# 42 Already // Anderson .Paak
# 43 The Seed (2.0) // The Roots
# 44 Booyah - Original Mix // Showtek
# 45 To the Top // Too Many Zooz
# 46 The Soundmaker // Rodrigo y Gabriela
# 47 The Blacker The Berry // Kendrick Lamar
# 48 Elbow Pain // Glue Trip
# 49 Can't Stop // Red Hot Chili Peppers

# %%
sp_ids = [item['id'] for item in tracks['items']]
sp_ids
# Out:
# ['6r7FXNO57mlZCBY6PXcZZT',
#  '7Ks4VCY1wFebnOdJrM13t6',
#  '276zciJ7Fg7Jk6Ta6QuLkp',
#  '37Tmv4NnfQeb0ZgUC4fOJj',
#  '3aGibUHhQyBsyumYHylw0K',
#  '7wdzLe2Gsx1RGqbvYZHASz',
#  '7KX65PC1UZuImsUInThbav',
#  '5PRExK60JlWq8jybMNrj71',
#  '1tL5a9jowsWMtn3wkFYsG9',
#  '70SjyVMzhmMeJQD8hOmIBp',
#  '0SMzXgUFqcAt0WNCsGm3tM',
#  '4ORadZjMm6szG6mf0rBLXI',
#  '1GGAFSOcU7nMNLVKZwWyju',
#  '7vjzFWG4neQ9YYMN9yZ9hr',
#  '60xaS8mYBKUW4VQQ666N0T',
#  '47aTIe7m6ZFYTh3k3RWukF',
#  '4bMIRaesSZwIldFWCGs96S',
#  '6rDBRNVPEHVWUCkDrUVY5a',
#  '2rmq49FcJ4U3wh1Z7C9UxE',
#  '3kxfsdsCpFgN412fpnW85Y',
#  '3bpdzTbrMTVmhSCZIOnP0a',
#  '0N3W5peJUQtI4eyR6GJT5O',
#  '5WNTvu2nQ4RO6GUMRrj2kf',
#  '35nTgQscqJHPc96HoRxfgt',
#  '2u5woInaGB7YASEd1CwGBJ',
#  '6CubWHZakFiId6yMAzrRQN',
#  '6K4t31amVTZDgR3sKmwUJJ',
#  '3ODXRUPL44f04cCacwiCLC',
#  '2UciqgwVDwro0fev3MFbxJ',
#  '2XTkpF9T2PKvcLgamGJGx1',
#  '5BMwpS4iYKR30kq9U9beaT',
#  '2X485T9Z5Ly0xyaghN73ed',
#  '439TlnnznSiBbQbgXiBqAd',
#  '4gQdwwPXSXnDkUh4jYqLoC',
#  '7twVmetQlugzgUqdMNjdJ4',
#  '22ff60cZy4APp7bzESHLR8',
#  '3bidbhpOYeV4knp8AIu8Xn',
#  '5n0CTysih20NYdT2S0Wpe8',
#  '2oaK4JLVnmRGIO9ytBE1bt',
#  '2aibwv5hGXSgw7Yru8IYTO',
#  '0FHoQy4FLym4eVn6d2JCx0',
#  '2ouDQcQR4aV33iXciWvWqk',
#  '0YOTE8vEGduSABT8QE55rK',
#  '1a6Jt6USVGKzbjYpcKMwPB',
#  '30BBwDTjwHQf1ixFGaE2o2',
#  '5UxbjTLzDV72IWWLzVLAiF',
#  '4qozE9YNw4RKITV5c2AF8A',
#  '5Mtt6tZSZA9cXTHGSGpyh0',
#  '6WvESq4vEfCqsVCiWl5o8t',
#  '3ZOEytgrvLwQaqXreDs2Jx']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='02c386b9bcfb43248ad7011c576c1e3f',
                                      client_secret='f2406ab918d349689325d2f6916aa656')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
audio_features = sp.audio_features(tracks=sp_ids)
assert len(sp_ids) == len(audio_features)
audio_features
# Out:
# [{'danceability': 0.88,
#   'energy': 0.821,
#   'key': 5,
#   'loudness': -2.545,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.0197,
#   'instrumentalness': 0.661,
#   'liveness': 0.234,
#   'valence': 0.575,
#   'tempo': 127.907,
#   'type': 'audio_features',
#   'id': '6r7FXNO57mlZCBY6PXcZZT',
#   'uri': 'spotify:track:6r7FXNO57mlZCBY6PXcZZT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6r7FXNO57mlZCBY6PXcZZT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6r7FXNO57mlZCBY6PXcZZT',
#   'duration_ms': 326888,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.787,
#   'key': 7,
#   'loudness': -6.754,
#   'mode': 1,
#   'speechiness': 0.265,
#   'acousticness': 0.359,
#   'instrumentalness': 2.76e-05,
#   'liveness': 0.26,
#   'valence': 0.507,
#   'tempo': 114.449,
#   'type': 'audio_features',
#   'id': '7Ks4VCY1wFebnOdJrM13t6',
#   'uri': 'spotify:track:7Ks4VCY1wFebnOdJrM13t6',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Ks4VCY1wFebnOdJrM13t6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Ks4VCY1wFebnOdJrM13t6',
#   'duration_ms': 287360,
#   'time_signature': 4},
#  {'danceability': 0.82,
#   'energy': 0.908,
#   'key': 10,
#   'loudness': -6.151,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.328,
#   'instrumentalness': 0.00155,
#   'liveness': 0.296,
#   'valence': 0.919,
#   'tempo': 98.381,
#   'type': 'audio_features',
#   'id': '276zciJ7Fg7Jk6Ta6QuLkp',
#   'uri': 'spotify:track:276zciJ7Fg7Jk6Ta6QuLkp',
#   'track_href': 'https://api.spotify.com/v1/tracks/276zciJ7Fg7Jk6Ta6QuLkp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/276zciJ7Fg7Jk6Ta6QuLkp',
#   'duration_ms': 176693,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.794,
#   'key': 5,
#   'loudness': -10.023,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.0614,
#   'instrumentalness': 0.0367,
#   'liveness': 0.33,
#   'valence': 0.931,
#   'tempo': 148.174,
#   'type': 'audio_features',
#   'id': '37Tmv4NnfQeb0ZgUC4fOJj',
#   'uri': 'spotify:track:37Tmv4NnfQeb0ZgUC4fOJj',
#   'track_href': 'https://api.spotify.com/v1/tracks/37Tmv4NnfQeb0ZgUC4fOJj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37Tmv4NnfQeb0ZgUC4fOJj',
#   'duration_ms': 348624,
#   'time_signature': 4},
#  {'danceability': 0.546,
#   'energy': 0.651,
#   'key': 1,
#   'loudness': -7.601,
#   'mode': 1,
#   'speechiness': 0.3,
#   'acousticness': 0.000739,
#   'instrumentalness': 0,
#   'liveness': 0.235,
#   'valence': 0.646,
#   'tempo': 77.878,
#   'type': 'audio_features',
#   'id': '3aGibUHhQyBsyumYHylw0K',
#   'uri': 'spotify:track:3aGibUHhQyBsyumYHylw0K',
#   'track_href': 'https://api.spotify.com/v1/tracks/3aGibUHhQyBsyumYHylw0K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3aGibUHhQyBsyumYHylw0K',
#   'duration_ms': 212653,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.886,
#   'key': 1,
#   'loudness': -5.322,
#   'mode': 1,
#   'speechiness': 0.0627,
#   'acousticness': 0.0196,
#   'instrumentalness': 1.72e-06,
#   'liveness': 0.236,
#   'valence': 0.89,
#   'tempo': 121.91,
#   'type': 'audio_features',
#   'id': '7wdzLe2Gsx1RGqbvYZHASz',
#   'uri': 'spotify:track:7wdzLe2Gsx1RGqbvYZHASz',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wdzLe2Gsx1RGqbvYZHASz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wdzLe2Gsx1RGqbvYZHASz',
#   'duration_ms': 231933,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.58,
#   'key': 7,
#   'loudness': -6.208,
#   'mode': 0,
#   'speechiness': 0.0278,
#   'acousticness': 0.357,
#   'instrumentalness': 0.000353,
#   'liveness': 0.436,
#   'valence': 0.655,
#   'tempo': 110.264,
#   'type': 'audio_features',
#   'id': '7KX65PC1UZuImsUInThbav',
#   'uri': 'spotify:track:7KX65PC1UZuImsUInThbav',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KX65PC1UZuImsUInThbav',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KX65PC1UZuImsUInThbav',
#   'duration_ms': 210300,
#   'time_signature': 4},
#  {'danceability': 0.81,
#   'energy': 0.5,
#   'key': 2,
#   'loudness': -15.012,
#   'mode': 1,
#   'speechiness': 0.165,
#   'acousticness': 0.591,
#   'instrumentalness': 0.066,
#   'liveness': 0.116,
#   'valence': 0.852,
#   'tempo': 112.959,
#   'type': 'audio_features',
#   'id': '5PRExK60JlWq8jybMNrj71',
#   'uri': 'spotify:track:5PRExK60JlWq8jybMNrj71',
#   'track_href': 'https://api.spotify.com/v1/tracks/5PRExK60JlWq8jybMNrj71',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PRExK60JlWq8jybMNrj71',
#   'duration_ms': 316653,
#   'time_signature': 4},
#  {'danceability': 0.679,
#   'energy': 0.374,
#   'key': 11,
#   'loudness': -10.565,
#   'mode': 0,
#   'speechiness': 0.0482,
#   'acousticness': 0.402,
#   'instrumentalness': 2.49e-05,
#   'liveness': 0.0541,
#   'valence': 0.871,
#   'tempo': 80.86,
#   'type': 'audio_features',
#   'id': '1tL5a9jowsWMtn3wkFYsG9',
#   'uri': 'spotify:track:1tL5a9jowsWMtn3wkFYsG9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1tL5a9jowsWMtn3wkFYsG9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1tL5a9jowsWMtn3wkFYsG9',
#   'duration_ms': 306800,
#   'time_signature': 4},
#  {'danceability': 0.732,
#   'energy': 0.789,
#   'key': 5,
#   'loudness': -3.717,
#   'mode': 0,
#   'speechiness': 0.0476,
#   'acousticness': 0.0459,
#   'instrumentalness': 3.11e-05,
#   'liveness': 0.123,
#   'valence': 0.607,
#   'tempo': 107.978,
#   'type': 'audio_features',
#   'id': '70SjyVMzhmMeJQD8hOmIBp',
#   'uri': 'spotify:track:70SjyVMzhmMeJQD8hOmIBp',
#   'track_href': 'https://api.spotify.com/v1/tracks/70SjyVMzhmMeJQD8hOmIBp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70SjyVMzhmMeJQD8hOmIBp',
#   'duration_ms': 160760,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.75,
#   'key': 6,
#   'loudness': -5.502,
#   'mode': 0,
#   'speechiness': 0.0583,
#   'acousticness': 0.137,
#   'instrumentalness': 3.53e-06,
#   'liveness': 0.197,
#   'valence': 0.88,
#   'tempo': 82.041,
#   'type': 'audio_features',
#   'id': '0SMzXgUFqcAt0WNCsGm3tM',
#   'uri': 'spotify:track:0SMzXgUFqcAt0WNCsGm3tM',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SMzXgUFqcAt0WNCsGm3tM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SMzXgUFqcAt0WNCsGm3tM',
#   'duration_ms': 202933,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.827,
#   'key': 10,
#   'loudness': -5.649,
#   'mode': 0,
#   'speechiness': 0.184,
#   'acousticness': 0.218,
#   'instrumentalness': 9.7e-05,
#   'liveness': 0.113,
#   'valence': 0.312,
#   'tempo': 106.989,
#   'type': 'audio_features',
#   'id': '4ORadZjMm6szG6mf0rBLXI',
#   'uri': 'spotify:track:4ORadZjMm6szG6mf0rBLXI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ORadZjMm6szG6mf0rBLXI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ORadZjMm6szG6mf0rBLXI',
#   'duration_ms': 267907,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.669,
#   'key': 5,
#   'loudness': -3.547,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.00386,
#   'instrumentalness': 2.01e-06,
#   'liveness': 0.519,
#   'valence': 0.855,
#   'tempo': 122.988,
#   'type': 'audio_features',
#   'id': '1GGAFSOcU7nMNLVKZwWyju',
#   'uri': 'spotify:track:1GGAFSOcU7nMNLVKZwWyju',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GGAFSOcU7nMNLVKZwWyju',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GGAFSOcU7nMNLVKZwWyju',
#   'duration_ms': 210467,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.952,
#   'key': 11,
#   'loudness': -3.641,
#   'mode': 0,
#   'speechiness': 0.134,
#   'acousticness': 0.000139,
#   'instrumentalness': 0.00283,
#   'liveness': 0.386,
#   'valence': 0.398,
#   'tempo': 170.058,
#   'type': 'audio_features',
#   'id': '7vjzFWG4neQ9YYMN9yZ9hr',
#   'uri': 'spotify:track:7vjzFWG4neQ9YYMN9yZ9hr',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vjzFWG4neQ9YYMN9yZ9hr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vjzFWG4neQ9YYMN9yZ9hr',
#   'duration_ms': 220573,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.777,
#   'key': 2,
#   'loudness': -5.729,
#   'mode': 1,
#   'speechiness': 0.195,
#   'acousticness': 0.0358,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.392,
#   'tempo': 111.921,
#   'type': 'audio_features',
#   'id': '60xaS8mYBKUW4VQQ666N0T',
#   'uri': 'spotify:track:60xaS8mYBKUW4VQQ666N0T',
#   'track_href': 'https://api.spotify.com/v1/tracks/60xaS8mYBKUW4VQQ666N0T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60xaS8mYBKUW4VQQ666N0T',
#   'duration_ms': 141542,
#   'time_signature': 4},
#  {'danceability': 0.856,
#   'energy': 0.733,
#   'key': 11,
#   'loudness': -2.473,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.149,
#   'instrumentalness': 0.649,
#   'liveness': 0.0777,
#   'valence': 0.738,
#   'tempo': 111.453,
#   'type': 'audio_features',
#   'id': '47aTIe7m6ZFYTh3k3RWukF',
#   'uri': 'spotify:track:47aTIe7m6ZFYTh3k3RWukF',
#   'track_href': 'https://api.spotify.com/v1/tracks/47aTIe7m6ZFYTh3k3RWukF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47aTIe7m6ZFYTh3k3RWukF',
#   'duration_ms': 107440,
#   'time_signature': 4},
#  {'danceability': 0.705,
#   'energy': 0.887,
#   'key': 4,
#   'loudness': -5.168,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.0323,
#   'instrumentalness': 0.000578,
#   'liveness': 0.227,
#   'valence': 0.873,
#   'tempo': 115.97,
#   'type': 'audio_features',
#   'id': '4bMIRaesSZwIldFWCGs96S',
#   'uri': 'spotify:track:4bMIRaesSZwIldFWCGs96S',
#   'track_href': 'https://api.spotify.com/v1/tracks/4bMIRaesSZwIldFWCGs96S',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4bMIRaesSZwIldFWCGs96S',
#   'duration_ms': 225427,
#   'time_signature': 4},
#  {'danceability': 0.371,
#   'energy': 0.866,
#   'key': 6,
#   'loudness': -4.202,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.0311,
#   'instrumentalness': 0.856,
#   'liveness': 0.426,
#   'valence': 0.123,
#   'tempo': 98.836,
#   'type': 'audio_features',
#   'id': '6rDBRNVPEHVWUCkDrUVY5a',
#   'uri': 'spotify:track:6rDBRNVPEHVWUCkDrUVY5a',
#   'track_href': 'https://api.spotify.com/v1/tracks/6rDBRNVPEHVWUCkDrUVY5a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rDBRNVPEHVWUCkDrUVY5a',
#   'duration_ms': 169604,
#   'time_signature': 5},
#  {'danceability': 0.644,
#   'energy': 0.479,
#   'key': 4,
#   'loudness': -8.352,
#   'mode': 1,
#   'speechiness': 0.177,
#   'acousticness': 0.169,
#   'instrumentalness': 0,
#   'liveness': 0.639,
#   'valence': 0.612,
#   'tempo': 79.929,
#   'type': 'audio_features',
#   'id': '2rmq49FcJ4U3wh1Z7C9UxE',
#   'uri': 'spotify:track:2rmq49FcJ4U3wh1Z7C9UxE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2rmq49FcJ4U3wh1Z7C9UxE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rmq49FcJ4U3wh1Z7C9UxE',
#   'duration_ms': 180680,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.356,
#   'key': 1,
#   'loudness': -10.425,
#   'mode': 1,
#   'speechiness': 0.0941,
#   'acousticness': 0.172,
#   'instrumentalness': 0.00943,
#   'liveness': 0.123,
#   'valence': 0.607,
#   'tempo': 160.033,
#   'type': 'audio_features',
#   'id': '3kxfsdsCpFgN412fpnW85Y',
#   'uri': 'spotify:track:3kxfsdsCpFgN412fpnW85Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kxfsdsCpFgN412fpnW85Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kxfsdsCpFgN412fpnW85Y',
#   'duration_ms': 326933,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.677,
#   'key': 1,
#   'loudness': -4.283,
#   'mode': 1,
#   'speechiness': 0.0959,
#   'acousticness': 0.116,
#   'instrumentalness': 0.000223,
#   'liveness': 0.371,
#   'valence': 0.548,
#   'tempo': 96.011,
#   'type': 'audio_features',
#   'id': '3bpdzTbrMTVmhSCZIOnP0a',
#   'uri': 'spotify:track:3bpdzTbrMTVmhSCZIOnP0a',
#   'track_href': 'https://api.spotify.com/v1/tracks/3bpdzTbrMTVmhSCZIOnP0a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bpdzTbrMTVmhSCZIOnP0a',
#   'duration_ms': 245160,
#   'time_signature': 4},
#  {'danceability': 0.884,
#   'energy': 0.657,
#   'key': 6,
#   'loudness': -4.569,
#   'mode': 0,
#   'speechiness': 0.0977,
#   'acousticness': 0.00589,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.489,
#   'tempo': 107.059,
#   'type': 'audio_features',
#   'id': '0N3W5peJUQtI4eyR6GJT5O',
#   'uri': 'spotify:track:0N3W5peJUQtI4eyR6GJT5O',
#   'track_href': 'https://api.spotify.com/v1/tracks/0N3W5peJUQtI4eyR6GJT5O',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0N3W5peJUQtI4eyR6GJT5O',
#   'duration_ms': 234693,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.476,
#   'key': 11,
#   'loudness': -7.168,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.217,
#   'instrumentalness': 0.414,
#   'liveness': 0.0889,
#   'valence': 0.0656,
#   'tempo': 109.015,
#   'type': 'audio_features',
#   'id': '5WNTvu2nQ4RO6GUMRrj2kf',
#   'uri': 'spotify:track:5WNTvu2nQ4RO6GUMRrj2kf',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WNTvu2nQ4RO6GUMRrj2kf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WNTvu2nQ4RO6GUMRrj2kf',
#   'duration_ms': 252110,
#   'time_signature': 4},
#  {'danceability': 0.672,
#   'energy': 0.732,
#   'key': 0,
#   'loudness': -5.96,
#   'mode': 1,
#   'speechiness': 0.246,
#   'acousticness': 0.442,
#   'instrumentalness': 0,
#   'liveness': 0.441,
#   'valence': 0.506,
#   'tempo': 94.016,
#   'type': 'audio_features',
#   'id': '35nTgQscqJHPc96HoRxfgt',
#   'uri': 'spotify:track:35nTgQscqJHPc96HoRxfgt',
#   'track_href': 'https://api.spotify.com/v1/tracks/35nTgQscqJHPc96HoRxfgt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35nTgQscqJHPc96HoRxfgt',
#   'duration_ms': 214230,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.861,
#   'key': 5,
#   'loudness': -5.821,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.0131,
#   'instrumentalness': 0.000209,
#   'liveness': 0.0751,
#   'valence': 0.778,
#   'tempo': 128.033,
#   'type': 'audio_features',
#   'id': '2u5woInaGB7YASEd1CwGBJ',
#   'uri': 'spotify:track:2u5woInaGB7YASEd1CwGBJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2u5woInaGB7YASEd1CwGBJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u5woInaGB7YASEd1CwGBJ',
#   'duration_ms': 331733,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.842,
#   'key': 0,
#   'loudness': -3.149,
#   'mode': 1,
#   'speechiness': 0.076,
#   'acousticness': 0.00428,
#   'instrumentalness': 3.03e-05,
#   'liveness': 0.16,
#   'valence': 0.7,
#   'tempo': 92.955,
#   'type': 'audio_features',
#   'id': '6CubWHZakFiId6yMAzrRQN',
#   'uri': 'spotify:track:6CubWHZakFiId6yMAzrRQN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6CubWHZakFiId6yMAzrRQN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6CubWHZakFiId6yMAzrRQN',
#   'duration_ms': 214397,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.74,
#   'key': 4,
#   'loudness': -4.083,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.0115,
#   'instrumentalness': 0.00678,
#   'liveness': 0.167,
#   'valence': 0.785,
#   'tempo': 116.879,
#   'type': 'audio_features',
#   'id': '6K4t31amVTZDgR3sKmwUJJ',
#   'uri': 'spotify:track:6K4t31amVTZDgR3sKmwUJJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6K4t31amVTZDgR3sKmwUJJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6K4t31amVTZDgR3sKmwUJJ',
#   'duration_ms': 216320,
#   'time_signature': 4},
#  {'danceability': 0.541,
#   'energy': 0.809,
#   'key': 8,
#   'loudness': -4.286,
#   'mode': 1,
#   'speechiness': 0.324,
#   'acousticness': 0.708,
#   'instrumentalness': 0,
#   'liveness': 0.72,
#   'valence': 0.753,
#   'tempo': 120.094,
#   'type': 'audio_features',
#   'id': '3ODXRUPL44f04cCacwiCLC',
#   'uri': 'spotify:track:3ODXRUPL44f04cCacwiCLC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ODXRUPL44f04cCacwiCLC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ODXRUPL44f04cCacwiCLC',
#   'duration_ms': 336013,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.497,
#   'key': 8,
#   'loudness': -7.661,
#   'mode': 1,
#   'speechiness': 0.681,
#   'acousticness': 0.115,
#   'instrumentalness': 0,
#   'liveness': 0.0898,
#   'valence': 0.345,
#   'tempo': 81.651,
#   'type': 'audio_features',
#   'id': '2UciqgwVDwro0fev3MFbxJ',
#   'uri': 'spotify:track:2UciqgwVDwro0fev3MFbxJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UciqgwVDwro0fev3MFbxJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UciqgwVDwro0fev3MFbxJ',
#   'duration_ms': 216727,
#   'time_signature': 4},
#  {'danceability': 0.365,
#   'energy': 0.804,
#   'key': 9,
#   'loudness': -5.922,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.104,
#   'instrumentalness': 6.58e-05,
#   'liveness': 0.15,
#   'valence': 0.577,
#   'tempo': 171.597,
#   'type': 'audio_features',
#   'id': '2XTkpF9T2PKvcLgamGJGx1',
#   'uri': 'spotify:track:2XTkpF9T2PKvcLgamGJGx1',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XTkpF9T2PKvcLgamGJGx1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XTkpF9T2PKvcLgamGJGx1',
#   'duration_ms': 268733,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.0809,
#   'key': 6,
#   'loudness': -19.346,
#   'mode': 0,
#   'speechiness': 0.0523,
#   'acousticness': 0.954,
#   'instrumentalness': 0.0233,
#   'liveness': 0.0935,
#   'valence': 0.204,
#   'tempo': 98.379,
#   'type': 'audio_features',
#   'id': '5BMwpS4iYKR30kq9U9beaT',
#   'uri': 'spotify:track:5BMwpS4iYKR30kq9U9beaT',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BMwpS4iYKR30kq9U9beaT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BMwpS4iYKR30kq9U9beaT',
#   'duration_ms': 111240,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.881,
#   'key': 1,
#   'loudness': -5.875,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.00462,
#   'instrumentalness': 0.0266,
#   'liveness': 0.111,
#   'valence': 0.577,
#   'tempo': 125.012,
#   'type': 'audio_features',
#   'id': '2X485T9Z5Ly0xyaghN73ed',
#   'uri': 'spotify:track:2X485T9Z5Ly0xyaghN73ed',
#   'track_href': 'https://api.spotify.com/v1/tracks/2X485T9Z5Ly0xyaghN73ed',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2X485T9Z5Ly0xyaghN73ed',
#   'duration_ms': 467587,
#   'time_signature': 4},
#  {'danceability': 0.487,
#   'energy': 0.729,
#   'key': 2,
#   'loudness': -6.815,
#   'mode': 1,
#   'speechiness': 0.271,
#   'acousticness': 0.0538,
#   'instrumentalness': 4.07e-06,
#   'liveness': 0.44,
#   'valence': 0.217,
#   'tempo': 91.048,
#   'type': 'audio_features',
#   'id': '439TlnnznSiBbQbgXiBqAd',
#   'uri': 'spotify:track:439TlnnznSiBbQbgXiBqAd',
#   'track_href': 'https://api.spotify.com/v1/tracks/439TlnnznSiBbQbgXiBqAd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/439TlnnznSiBbQbgXiBqAd',
#   'duration_ms': 350120,
#   'time_signature': 4},
#  {'danceability': 0.592,
#   'energy': 0.861,
#   'key': 1,
#   'loudness': -5.177,
#   'mode': 1,
#   'speechiness': 0.249,
#   'acousticness': 0.024,
#   'instrumentalness': 0,
#   'liveness': 0.492,
#   'valence': 0.794,
#   'tempo': 90.238,
#   'type': 'audio_features',
#   'id': '4gQdwwPXSXnDkUh4jYqLoC',
#   'uri': 'spotify:track:4gQdwwPXSXnDkUh4jYqLoC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4gQdwwPXSXnDkUh4jYqLoC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4gQdwwPXSXnDkUh4jYqLoC',
#   'duration_ms': 196440,
#   'time_signature': 4},
#  {'danceability': 0.893,
#   'energy': 0.48,
#   'key': 9,
#   'loudness': -5.493,
#   'mode': 1,
#   'speechiness': 0.056,
#   'acousticness': 0.0903,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.968,
#   'tempo': 123.98,
#   'type': 'audio_features',
#   'id': '7twVmetQlugzgUqdMNjdJ4',
#   'uri': 'spotify:track:7twVmetQlugzgUqdMNjdJ4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7twVmetQlugzgUqdMNjdJ4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7twVmetQlugzgUqdMNjdJ4',
#   'duration_ms': 202067,
#   'time_signature': 4},
#  {'danceability': 0.766,
#   'energy': 0.844,
#   'key': 10,
#   'loudness': -3.851,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.0261,
#   'instrumentalness': 0.605,
#   'liveness': 0.18,
#   'valence': 0.835,
#   'tempo': 129.323,
#   'type': 'audio_features',
#   'id': '22ff60cZy4APp7bzESHLR8',
#   'uri': 'spotify:track:22ff60cZy4APp7bzESHLR8',
#   'track_href': 'https://api.spotify.com/v1/tracks/22ff60cZy4APp7bzESHLR8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22ff60cZy4APp7bzESHLR8',
#   'duration_ms': 191573,
#   'time_signature': 4},
#  {'danceability': 0.641,
#   'energy': 0.922,
#   'key': 2,
#   'loudness': -4.457,
#   'mode': 1,
#   'speechiness': 0.0786,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.0862,
#   'valence': 0.847,
#   'tempo': 146.078,
#   'type': 'audio_features',
#   'id': '3bidbhpOYeV4knp8AIu8Xn',
#   'uri': 'spotify:track:3bidbhpOYeV4knp8AIu8Xn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3bidbhpOYeV4knp8AIu8Xn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bidbhpOYeV4knp8AIu8Xn',
#   'duration_ms': 258343,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.623,
#   'key': 0,
#   'loudness': -5.655,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.392,
#   'instrumentalness': 0.000453,
#   'liveness': 0.0992,
#   'valence': 0.298,
#   'tempo': 77.861,
#   'type': 'audio_features',
#   'id': '5n0CTysih20NYdT2S0Wpe8',
#   'uri': 'spotify:track:5n0CTysih20NYdT2S0Wpe8',
#   'track_href': 'https://api.spotify.com/v1/tracks/5n0CTysih20NYdT2S0Wpe8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5n0CTysih20NYdT2S0Wpe8',
#   'duration_ms': 225973,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.742,
#   'key': 5,
#   'loudness': -6.777,
#   'mode': 0,
#   'speechiness': 0.0716,
#   'acousticness': 0.0722,
#   'instrumentalness': 0.0199,
#   'liveness': 0.11,
#   'valence': 0.197,
#   'tempo': 91.959,
#   'type': 'audio_features',
#   'id': '2oaK4JLVnmRGIO9ytBE1bt',
#   'uri': 'spotify:track:2oaK4JLVnmRGIO9ytBE1bt',
#   'track_href': 'https://api.spotify.com/v1/tracks/2oaK4JLVnmRGIO9ytBE1bt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2oaK4JLVnmRGIO9ytBE1bt',
#   'duration_ms': 302000,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.895,
#   'key': 11,
#   'loudness': -3.682,
#   'mode': 1,
#   'speechiness': 0.0504,
#   'acousticness': 0.127,
#   'instrumentalness': 1.16e-05,
#   'liveness': 0.141,
#   'valence': 0.625,
#   'tempo': 104.458,
#   'type': 'audio_features',
#   'id': '2aibwv5hGXSgw7Yru8IYTO',
#   'uri': 'spotify:track:2aibwv5hGXSgw7Yru8IYTO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2aibwv5hGXSgw7Yru8IYTO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aibwv5hGXSgw7Yru8IYTO',
#   'duration_ms': 335067,
#   'time_signature': 4},
#  {'danceability': 0.345,
#   'energy': 0.924,
#   'key': 0,
#   'loudness': -4.345,
#   'mode': 0,
#   'speechiness': 0.278,
#   'acousticness': 0.279,
#   'instrumentalness': 0,
#   'liveness': 0.279,
#   'valence': 0.869,
#   'tempo': 95.26,
#   'type': 'audio_features',
#   'id': '0FHoQy4FLym4eVn6d2JCx0',
#   'uri': 'spotify:track:0FHoQy4FLym4eVn6d2JCx0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0FHoQy4FLym4eVn6d2JCx0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FHoQy4FLym4eVn6d2JCx0',
#   'duration_ms': 168158,
#   'time_signature': 4},
#  {'danceability': 0.832,
#   'energy': 0.439,
#   'key': 9,
#   'loudness': -10.979,
#   'mode': 0,
#   'speechiness': 0.0715,
#   'acousticness': 0.513,
#   'instrumentalness': 0.0195,
#   'liveness': 0.119,
#   'valence': 0.635,
#   'tempo': 97.996,
#   'type': 'audio_features',
#   'id': '2ouDQcQR4aV33iXciWvWqk',
#   'uri': 'spotify:track:2ouDQcQR4aV33iXciWvWqk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ouDQcQR4aV33iXciWvWqk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ouDQcQR4aV33iXciWvWqk',
#   'duration_ms': 152390,
#   'time_signature': 4},
#  {'danceability': 0.506,
#   'energy': 0.671,
#   'key': 6,
#   'loudness': -5.802,
#   'mode': 0,
#   'speechiness': 0.306,
#   'acousticness': 0.0716,
#   'instrumentalness': 0.00865,
#   'liveness': 0.765,
#   'valence': 0.482,
#   'tempo': 75.014,
#   'type': 'audio_features',
#   'id': '0YOTE8vEGduSABT8QE55rK',
#   'uri': 'spotify:track:0YOTE8vEGduSABT8QE55rK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0YOTE8vEGduSABT8QE55rK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0YOTE8vEGduSABT8QE55rK',
#   'duration_ms': 194011,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.957,
#   'key': 7,
#   'loudness': -2.282,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.039,
#   'instrumentalness': 0,
#   'liveness': 0.133,
#   'valence': 0.966,
#   'tempo': 111.119,
#   'type': 'audio_features',
#   'id': '1a6Jt6USVGKzbjYpcKMwPB',
#   'uri': 'spotify:track:1a6Jt6USVGKzbjYpcKMwPB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1a6Jt6USVGKzbjYpcKMwPB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1a6Jt6USVGKzbjYpcKMwPB',
#   'duration_ms': 267933,
#   'time_signature': 4},
#  {'danceability': 0.738,
#   'energy': 0.953,
#   'key': 11,
#   'loudness': -2.633,
#   'mode': 1,
#   'speechiness': 0.124,
#   'acousticness': 0.00968,
#   'instrumentalness': 0.0115,
#   'liveness': 0.0501,
#   'valence': 0.54,
#   'tempo': 127.989,
#   'type': 'audio_features',
#   'id': '30BBwDTjwHQf1ixFGaE2o2',
#   'uri': 'spotify:track:30BBwDTjwHQf1ixFGaE2o2',
#   'track_href': 'https://api.spotify.com/v1/tracks/30BBwDTjwHQf1ixFGaE2o2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/30BBwDTjwHQf1ixFGaE2o2',
#   'duration_ms': 311211,
#   'time_signature': 4},
#  {'danceability': 0.424,
#   'energy': 0.639,
#   'key': 0,
#   'loudness': -6.227,
#   'mode': 1,
#   'speechiness': 0.0594,
#   'acousticness': 0.00693,
#   'instrumentalness': 0.913,
#   'liveness': 0.602,
#   'valence': 0.493,
#   'tempo': 177.978,
#   'type': 'audio_features',
#   'id': '5UxbjTLzDV72IWWLzVLAiF',
#   'uri': 'spotify:track:5UxbjTLzDV72IWWLzVLAiF',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UxbjTLzDV72IWWLzVLAiF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UxbjTLzDV72IWWLzVLAiF',
#   'duration_ms': 199750,
#   'time_signature': 4},
#  {'danceability': 0.514,
#   'energy': 0.741,
#   'key': 4,
#   'loudness': -7.914,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.888,
#   'instrumentalness': 0.81,
#   'liveness': 0.105,
#   'valence': 0.87,
#   'tempo': 134.733,
#   'type': 'audio_features',
#   'id': '4qozE9YNw4RKITV5c2AF8A',
#   'uri': 'spotify:track:4qozE9YNw4RKITV5c2AF8A',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qozE9YNw4RKITV5c2AF8A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qozE9YNw4RKITV5c2AF8A',
#   'duration_ms': 292133,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.852,
#   'key': 10,
#   'loudness': -4.08,
#   'mode': 0,
#   'speechiness': 0.305,
#   'acousticness': 0.00713,
#   'instrumentalness': 0,
#   'liveness': 0.463,
#   'valence': 0.27,
#   'tempo': 176.058,
#   'type': 'audio_features',
#   'id': '5Mtt6tZSZA9cXTHGSGpyh0',
#   'uri': 'spotify:track:5Mtt6tZSZA9cXTHGSGpyh0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Mtt6tZSZA9cXTHGSGpyh0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Mtt6tZSZA9cXTHGSGpyh0',
#   'duration_ms': 328827,
#   'time_signature': 4},
#  {'danceability': 0.751,
#   'energy': 0.46,
#   'key': 9,
#   'loudness': -7.662,
#   'mode': 0,
#   'speechiness': 0.0326,
#   'acousticness': 0.747,
#   'instrumentalness': 0.139,
#   'liveness': 0.192,
#   'valence': 0.405,
#   'tempo': 89.93,
#   'type': 'audio_features',
#   'id': '6WvESq4vEfCqsVCiWl5o8t',
#   'uri': 'spotify:track:6WvESq4vEfCqsVCiWl5o8t',
#   'track_href': 'https://api.spotify.com/v1/tracks/6WvESq4vEfCqsVCiWl5o8t',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WvESq4vEfCqsVCiWl5o8t',
#   'duration_ms': 333519,
#   'time_signature': 4},
#  {'danceability': 0.618,
#   'energy': 0.938,
#   'key': 9,
#   'loudness': -3.442,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0179,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.875,
#   'tempo': 91.455,
#   'type': 'audio_features',
#   'id': '3ZOEytgrvLwQaqXreDs2Jx',
#   'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZOEytgrvLwQaqXreDs2Jx',
#   'duration_ms': 269000,
#   'time_signature': 4}]

# %%
df = pd.DataFrame(audio_features)
df.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.019700  https://api.spotify.com/v1/audio-analysis/6r7F...
# 1      0.359000  https://api.spotify.com/v1/audio-analysis/7Ks4...
# 2      0.328000  https://api.spotify.com/v1/audio-analysis/276z...
# 3      0.061400  https://api.spotify.com/v1/audio-analysis/37Tm...
# 4      0.000739  https://api.spotify.com/v1/audio-analysis/3aGi...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.880       326888   0.821  6r7FXNO57mlZCBY6PXcZZT
# 1         0.509       287360   0.787  7Ks4VCY1wFebnOdJrM13t6
# 2         0.820       176693   0.908  276zciJ7Fg7Jk6Ta6QuLkp
# 3         0.733       348624   0.794  37Tmv4NnfQeb0ZgUC4fOJj
# 4         0.546       212653   0.651  3aGibUHhQyBsyumYHylw0K
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.661000    5     0.234    -2.545     0       0.1180  127.907
# 1          0.000028    7     0.260    -6.754     1       0.2650  114.449
# 2          0.001550   10     0.296    -6.151     0       0.1240   98.381
# 3          0.036700    5     0.330   -10.023     1       0.0307  148.174
# 4          0.000000    1     0.235    -7.601     1       0.3000   77.878
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/6r7FXNO57mlZ...
# 1               4  https://api.spotify.com/v1/tracks/7Ks4VCY1wFeb...
# 2               4  https://api.spotify.com/v1/tracks/276zciJ7Fg7J...
# 3               4  https://api.spotify.com/v1/tracks/37Tmv4NnfQeb...
# 4               4  https://api.spotify.com/v1/tracks/3aGibUHhQyBs...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:6r7FXNO57mlZCBY6PXcZZT    0.575
# 1  audio_features  spotify:track:7Ks4VCY1wFebnOdJrM13t6    0.507
# 2  audio_features  spotify:track:276zciJ7Fg7Jk6Ta6QuLkp    0.919
# 3  audio_features  spotify:track:37Tmv4NnfQeb0ZgUC4fOJj    0.931
# 4  audio_features  spotify:track:3aGibUHhQyBsyumYHylw0K    0.646

# %%
# LET n = number of songs
# LET m = number of audio features
feature_MUSIC_dict = {
    'danceability': np.array([-0.37, 0.05, -0.35, 0.08, 0.43]),
    'energy': np.array([-0.64, -0.46, -0.13, 0.66, -0.03]),
    'instrumentalness': np.array([0.20, -0.47, 0.28, 0.09, -0.01]),
    'liveness': np.array([-0.69, -0.12, -0.07, 0.43, 0.02]),
    'loudness': np.array([-0.58, -0.19, -0.44, 0.79, -0.21]),
    'valence': np.array([-0.04, 0.18, 0.24, -0.34, 0.18]),
}
# feature_MUSIC_matrix -> m x 5 matrix, where m is the number of audio features in feature_MUSIC_dict
feature_MUSIC_matrix = [MUSIC for MUSIC in feature_MUSIC_dict.values()]

def get_MUSIC(sub_df):
    # song_vectors -> n x m matrix, where m is the number of audio features in feature_MUSIC_dict
    song_vectors = sub_df[list(feature_MUSIC_dict.keys())].values
    
    # unweighted_MUSIC_vals -> n x 5 matrix
    unweighted_MUSIC_vals = song_vectors @ feature_MUSIC_matrix

    return list(np.mean(unweighted_MUSIC_vals, axis=0))

MUSIC = get_MUSIC(df)
MUSIC
# Out:
# [2.651562142519999,
#  0.8866577970780001,
#  2.5151982915280002,
#  -4.368227499866,
#  1.6471934888740005]

# %%
user_df = pd.read_hdf('data/user_df.h5')

# %%
user_df.tail()
# Out:
#                                                user_id  \
# sparse_index
# 1107608       ffffdc6c89988cd6119067769162948eacf8b670
# 1107609       ffffe07df4bb5fd929efe42c5728f3a0c1621277
# 1107610       fffff3e690fcda840b716ce7249d8935ff3323fc
# 1107611       fffff67d54a40927c93d03bd6c816b034b59f087
# 1107612       fffff9534445f481b6ab91c345500083d2ce4df1
#
#                                                           MUSIC  num_songs  \
# sparse_index
# 1107608       [2.8244128469444445, 0.8760942110694443, 2.575...         19
# 1107609       [4.002255443599999, 1.44013909754, 3.490590261...          5
# 1107610       [3.4351916499999997, 1.1264846787499998, 2.987...          4
# 1107611       [6.289073388259258, 1.9713095135166667, 5.2253...         34
# 1107612       [5.115677008573773, 1.6343121939909835, 4.2392...         20
#
#               is_test                                song_sparse_indices
# sparse_index
# 1107608         False  [132465, 132465, 132465, 132465, 105914, 81643...
# 1107609         False             [94818, 148217, 102368, 113863, 59720]
# 1107610         False                      [146129, 128807, 24213, 7403]
# 1107611         False  [118130, 15702, 8579, 94850, 101212, 158188, 1...
# 1107612         False  [146129, 118303, 152672, 123708, 111087, 13886...

# %%
user_row = pd.DataFrame([{
    'sparse_index': 69696969,
#     'user_id': 'spotify_user',
    'MUSIC': MUSIC,
#     'num_songs': 0,
#     'is_test':
    'song_sparse_indices': []
}])
user_row.set_index('sparse_index', inplace=True)
# user_row.head()
new_user_df = user_df.append(user_row)
new_user_df.tail()
# Out:
# /Users/nolandey/anaconda/envs/tensorflow3/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#                                                           MUSIC is_test  \
# sparse_index
# 1107609       [4.002255443599999, 1.44013909754, 3.490590261...   False
# 1107610       [3.4351916499999997, 1.1264846787499998, 2.987...   False
# 1107611       [6.289073388259258, 1.9713095135166667, 5.2253...   False
# 1107612       [5.115677008573773, 1.6343121939909835, 4.2392...   False
# 69696969      [2.651562142519999, 0.8866577970780001, 2.5151...     NaN
#
#               num_songs                                song_sparse_indices  \
# sparse_index
# 1107609             5.0             [94818, 148217, 102368, 113863, 59720]
# 1107610             4.0                      [146129, 128807, 24213, 7403]
# 1107611            34.0  [118130, 15702, 8579, 94850, 101212, 158188, 1...
# 1107612            20.0  [146129, 118303, 152672, 123708, 111087, 13886...
# 69696969            NaN                                                 []
#
#                                                user_id
# sparse_index
# 1107609       ffffe07df4bb5fd929efe42c5728f3a0c1621277
# 1107610       fffff3e690fcda840b716ce7249d8935ff3323fc
# 1107611       fffff67d54a40927c93d03bd6c816b034b59f087
# 1107612       fffff9534445f481b6ab91c345500083d2ce4df1
# 69696969                                           NaN

# %%
song_df = pd.read_hdf('data/song_df.h5')
song_df['spotify_id']
# Out:
# sparse_index
# 4785      4nuY11Vo1Yd5xMHhLfDKe9
# 7052      72PoJMDfdaw9gGECgA9kTZ
# 14453     2HPwuvT6HKngPSynOCi6Lb
# 20354     4KJ2K2j2ywVs80Fv7YSGZH
# 21408     5WjXULJvSlMxuies9diz1Q
# 22178     1bqi9YEdZweX9H6JuSQ6Qw
# 29123     5vNs7tNo0ayg5h2M4CMjtm
# 34309     4tjBDR8r3kxBXxQPeRTQgu
# 43845     2iY7jqy8zBlbk5RliSfTH1
# 44717     2WuSOPd7FlamTbsEK4oNZS
# 56699     5gt7UxeqKqaZjoBPE6Nz0R
# 57197     6hiUYBPiNeAEI3TknyH4wk
# 61666     0lkptoTrRGElC6MitvcdDp
# 63667     13dnmgHJQnbfH2XKPMMvVK
# 78229     3858gP4ZcAJKVl5pFQpTTo
# 81260     4hFTluJg9lI9MKx9NBXtAW
# 86300     5kvTz88kWSUjKT5a9jyZYh
# 86987     0pfG8LwO7hSdHe6hTgc6a6
# 88777     33hfrHygFzuNVpLkApZS7J
# 105444    2sl7XiRcoeSuJb7DV6joXY
# 106641    14NuOzRP6xp6xhVt2V5WIf
# 109029    1OJLduh678i1JCWi61ENLX
# 118961    5s0ZhaNkSVGvEd9mhClyQ9
# 120627    1i3NFqcXfBGWCgbZ8ud0p2
# 121353    3r1cfu7qDpEP3A80TGDzsH
# 123028    2WFWYqJlPtMav8b0GVVp8v
# 128522    527bOnXnTSSPOk1NMU0kgR
# 134692    2L4no3iw54gGX1ZwCNfYSL
# 135296    2cxBghmihWrxa1pYymuOCO
# 140451    37mzZTW41JzEMR0sFSipiW
#                    ...
# 148422    04pjKIZYw2iABerSePnGbz
# 32759     3yYsp20NQ22UpeNTTOvIvx
# 138874    3W3w908EKyv2ENnYkdflai
# 162734    1EuL4jFcaWPql7nvVI53XE
# 37317     4vLQVXFdg92Nlj3P1gJqBY
# 25806     07BxdMSzN753088h5Cpa32
# 127385    63nemNHC402usXjG0XdkHS
# 66950     0HW1M8IApLYp4V1fT0t4Ox
# 162588    5BHcPeo0HoAQTuwqyGfWcw
# 24246     4kzRFPq10PmypS81OSJEAR
# 40328     2W0CRiQBvLaE8BOXat2xJi
# 63377     2seAghw8sQBIfOlHSNHaV8
# 89956     6yGZ5QSUNo330sWdfoz9Zc
# 47524     0HnhiSJR172jYzp7lZsMk0
# 141051    1syddJgkjHA3HoV1dbH8Ra
# 3220      62lJf1uAY7hUGLbZ01TYiU
# 75296     1ZHWkVInACJq2h0ryJw0cP
# 162177    2FDQFqMy4n4uwCCSQA4BIz
# 90925     5ilFM1qLTLQqtHa1KNbxVX
# 131479    3A0UeP38LYEZkNVhwFttnz
# 128440    3Qd4GDgZM7YOsGLe56rrhJ
# 153598    4jQ4fVM2PtVguXuXqbDuSL
# 135156    30QkEqWuBIrC5WpAUBv5o0
# 162659    19sazrVoIIh14q7HoMAmd3
# 70295     07Tl9C0ZMOuKPGoi9adQco
# 112149    4sHnnRgOuL3EcYFeJSQO4o
# 73088     22vqoFAxDTDldM0yp4Cr09
# 74324     5dFPWGROxXRvnqwrBzAUA4
# 167917    3bwYZksm5ITcdTkY7Q9Ih0
# 150544    4oW4RCST3S5kpNLBEy1nJR
# Name: spotify_id, Length: 168842, dtype: object

# %%
song_df.loc[[4785, 7052]]['spotify_id'].to_list()
# Out:
# ['4nuY11Vo1Yd5xMHhLfDKe9', '72PoJMDfdaw9gGECgA9kTZ']
