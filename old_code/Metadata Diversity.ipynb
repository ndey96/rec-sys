# %% [markdown]
# # Metadata Diversity
#
# Given a list of track_id's, the metadata diversity of the list is:
#
# List_Diversity = (A)num_genres + (B)num_albums + (C)num_artists + (D)num_decades + ...
# Where A,B,C,D,... are positive constants

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('msd_subset_metadata.csv', index_col=0)

# %%
df.head()
# Out:
#    Unnamed: 0.1                           artist_mbid             artist_name  \
# 0             4  0e6524bd-6641-46a6-bce5-96f06c19aa46  Orlando Pops Orchestra
# 1             8  37c78aeb-d196-42b5-b991-6afb4fc9bc2e           Dead Kennedys
# 2            10  17e137fb-59e5-4fd7-af48-afc34995396c                  Atreyu
# 3            11  e8143d56-f2e9-4122-9666-6aa5352dadcd                Mistress
# 4            12  2e3b75d8-00a8-486a-b4e7-a1f8f65e64c9            Shadows Fall
#
#    artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 0               -1           0.0  199.99302     0.0   10   -16.477     1
# 1             6004           0.0  216.84200     0.0   10    -4.264     1
# 2               -1           0.0  218.90567     0.0    0    -4.707     0
# 3           160877           0.0  580.70159     0.0    0    -4.523     1
# 4            12510           0.0  283.48036     0.0    0    -4.076     0
#
# ...

# %%
df[df['track_id'].isin(['TRARRZU128F4253CA2', 'TRARRJL128F92DED0E'])].head()
# Out:
#    Unnamed: 0                           artist_mbid    artist_name  \
# 0           0  c43bb0d6-94d7-410f-80fb-e5a243b18d23        Raphaël
# 1           1  a69cd724-2f57-4ed0-bfed-ba20401eb84c  Julie Zenatti
#
#    artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 0             2676           0.0  148.74077     0.0    0    -9.636     1
# 1             5772           0.0  252.99546     0.0    1   -11.061     0
#
#                                    release  release_7digitalid  \
# 0  Je Sais Que La Terre Est Plate (Deluxe)              275907
# 1                               Comme Vous              382807
#
#    song_hotttnesss             song_id    tempo  time_signature  \
# 0         0.547953  SOGSMXL12A81C23D88  124.059               4
# 1         0.475638  SOMBCOW12AAF3B229F   80.084               4
#
#                             title  track_7digitalid            track_id  year
# ...

# %%
def metadata_diversity(track_ids):
    df = pd.read_csv('song_data.csv')
    df = df[df['track_id'].isin(track_ids)]
    
    diversity = 0
    diversity += 1*df['genre'].nunique() # genres
    diversity += 1*df['release_7digitalid'].nunique() # albums
    diversity += 1*df['artist_name'].nunique() # artists
    diversity += 1*df['year'].nunique() # years
    diversity += 1*np.floor(df['year']/10).nunique() # decades
    diversity += 1*np.round(df['duration']/60).nunique() # durations in minutes
    diversity += 1*np.round(df['tempo']/10).nunique() # tempo 10s of BMP
    
    return diversity

# %%
metadata_diversity(['TRARRZU128F4253CA2', 'TRARRJL128F92DED0E'])
# Out:
# 11
