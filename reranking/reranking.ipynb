# %%
# provided list - m songs ranked from best to worst in terms of relevance
# old output list - top n songs
# new output list - make minimum number of replacements to top n in order to satisfy diversity score

# %%
import numpy as np
import random
import csv
import pandas as pd

# %%
# key parameters

dimensionality = 50
m = 40
n = 10
min_diversity_score = 0.5

# %%
# generate dummy data

ideal_vector = np.random.uniform(-10,10,size=dimensionality)

provided_list = []

for i in range(m):
    provided_list.append(np.random.uniform(-10,10,size=dimensionality))
    
# sort provided_list from most to least relevant

dists = []
for vector in provided_list:
    dists.append(np.linalg.norm(ideal_vector - vector))
    
provided_list = [x for _,x in sorted(zip(dists, provided_list))]

# %%
# extract set of 10000 real song vectors, name, artist & genre into 2d list

song_id_vector_dict = np.load('data/song_embeddings.npy').item()
vector_song_id_dict = dict((str(v),k) for k,v in song_id_vector_dict.items())

# %%
song_vector_list = list(song_id_vector_dict.values())

# %%
# randomly select 10000 song_ids from the dict

d = list(song_id_vector_dict.keys()) 

song_id_list = random.sample(list(d), 10000)

# create 2d array where each entry of outer array is length 4 list of song_id, title, artist, genre, embedding list

df = pd.read_csv('data/full_msd.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                              artist_mbid        artist_name  \
# 0           0  b'bc30924c-1900-41c3-9a97-41a93433836f'     b'Baka Beyond'
# 1           1  b'4cda00d8-55d3-42cd-b5e3-5e1934406eaa'  b'The Fleetwoods'
# 2           2  b'29762c82-bb92-4acd-b1fb-09cc4da250d2'    b'Joe Satriani'
# 3           3  b'913096b7-10dc-41ca-9777-f299df45e9e2'             b'BIZ'
# 4           4  b'e4cfb284-9ab1-47f0-a725-082f84275a16'    b'Memphis Slim'
#
#    artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 0               -1           0.0  368.14322     0.0    9   -11.482     0
# 1             3031           0.0  175.59465     0.0    5   -15.193     1
# 2             8426           0.0  254.85016     0.0    7    -4.707     1
# 3            59280           0.0  233.40363     0.0    9    -5.972     1
# 4            19214           0.0  110.62812     0.0    5   -20.100     1
#
#                                              release  release_7digitalid  \
# 0                                b'The Meeting Pool'               38594
# 1  b'Come Softly To Me: The Very Best Of The Flee...              160575
# 2                                  b'Super Colossal'              308005
# 3                            b'Long Way Down Single'              195821
# 4                  b'Essential Blues Grooves Vol. 1'              599348
#
#    song_hotttnesss                song_id    tempo  time_signature  \
# 0         0.355286  b'SOXFJZQ12A6D4F81FB'  139.092               4
# 1         0.310792  b'SOMSPXD12A8C139F36'   87.650               4
# 2         0.693272  b'SOSIYAD12A8C14097F'   87.875               4
# 3              NaN  b'SODXCXN12A8C135FDD'   97.997               4
# 4              NaN  b'SODKHJS12AB0183BF0'  200.962               1
#
#                         title  track_7digitalid               track_id  year
# 0  b'Journey (Album Version)'            412977  b'TRCCCRP128F147BEFA'  1995
# 1           b'Ten Times Blue'           1694460  b'TRCCCDI128F427CC1F'  1993
# 2             b"It's So Good"           3473087  b'TRCCCMQ128F42AE752'  2006
# 3                   b'Ghosts'           2130366  b'TRCCCKF128F424C3D3'     0
# 4    b'Baby Please Come Home'           6650421  b'TRCCCFH12903CEBC70'     0

# %%
def prepare_song_id(song_id):
    return ('b\'' + song_id + '\'')

# %%
print(df.loc[(df['song_id'] == prepare_song_id(song_id_list[1]))])
# Out:
#         Unnamed: 0                              artist_mbid artist_name  \
# 766409      766409  b'633c13a3-335a-466f-8e01-535837faeff5'      b'Ayo'
#
#         artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 766409               -1           0.0  165.53751     0.0    9    -8.931     0
#
#                    release  release_7digitalid  song_hotttnesss  \
# 766409  b'Gravity At Last'              393852         0.728083
#
#                       song_id    tempo  time_signature                 title  \
# 766409  b'SOVIHIT12AB0180ECD'  127.398               4  b'Get Out Of My Way'
#
#         track_7digitalid               track_id  year
# 766409           4369491  b'TRSXWHS128F92F732F'  2008

# %%
# calculate diversity of top n vectors

def get_diversity(song_vector_list):
    
    sim = 0
    
    n = len(song_vector_list)
    
    for i in range(n):
        for j in range(n):
            sim += 1 - np.linalg.norm(song_vector_list[i]-song_vector_list[j])
            
    return sim/((n/2)*(n-1))

# %%
provided_list = random.sample(song_vector_list, 100)
get_diversity(provided_list)
# Out:
# 1.925528494977808

# %%
song_id = vector_song_id_dict[str(song_vector_list[0])]
print(song_id)
# Out:
# SOAKIMP12A8C130995

# %%
# swap until diversity of top n vectors > min_diversity_score

ideal_vector = np.random.uniform(-10,10,size=dimensionality)

# %%
# test out diversity levels

recommendations = np.load('data/recommendations.npy')

print(recommendations.shape)

print(recommendations[0])
# Out:
# (1000, 100, 2)
# [['SOBONKR12A58A7A7E0' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOAUWYT12A81C206F1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOPUCYA12A8C13A694' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOFLJQZ12A6D4FADA6' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOAXGDH12A8C13F8A1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHTKMO12AB01843B0' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSXLTC12AF72A7F54' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOFRQTD12A81C233C0' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOVDSJC12A58A7A271' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SORJICW12A8C13640D' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOUFTBI12AB0183F65' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOBOUPA12A6D4F81F1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOVWBYM12A6D4F8A22' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOUNZHU12A8AE47481' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOZVVRE12A8C143150' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOTCMDJ12A6D4F8528' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOPSOHT12A67AE0235' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOXLOQG12AF72A2D55' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SONYKOW12AB01849C9' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOEGIYH12A6D4FC0E3' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOQZYQH12A8AE468E5' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOIKQFR12A6310F2A6' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOTCWRK12AB017E47D' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOOFYTN12A6D4F9B35' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOIBCIC12A58A7B55B' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSYOHI12A8C144584' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOBABRB12A6701DF4B' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOIZFTE12AB0186842' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMLYJD12A58A7B155' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHFJAQ12AB017E4AF' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOEOLGZ12A8C134706' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOJYISZ12A8C135F5A' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SODJWHY12A8C142CCE' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOBMKJU12A6D4F7128' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOWRREB12A6D4FA7CB' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMCAFM12A58A7B024' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOBFRNE12A6D4F7995' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOZCDWG12A6D4F81E1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SODEGIQ12A6D4FC6E3' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOXWYZP12AF72A42A6' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOLRGVL12A8C143BC3' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SONHWUN12AC468C014' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOQPGDF12AB01858C5' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOWEHOM12A6BD4E09E' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOVAGPG12AB0189963' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHWXEU12A8C1320D1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOPAYPV12AB017DB0C' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOACBLB12AB01871C7' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSJSSU12A6D4F8F41' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOJOJUN12A8AE47E1D' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOLFXKT12AB017E3E0' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHFNKO12AB017C772' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOAVFLR12A8C138576' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SODASIJ12A6D4F5D89' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMMONH12A6D4F41CD' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOBRHVR12A8C133F35' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOVIZNF12AF72A710A' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOLHTJY12A58A7AFE7' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOPABZM12A6D4FC668' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSCIZP12AB0181D2F' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOTWNDJ12A8C143984' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSLQGG12A6D4F5045' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SONGTTS12A6701E59A' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOSAZWK12AC468D8C2' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOOWVNN12A8C140775' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHYLXU12A8C139492' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOKUPAO12AB018D576' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SODCNJX12A6D4F93CB' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMESIV12A6D4FC6F2' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOVDLZN12AB0185BEA' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOOGNOZ12AAF3B2936' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOFKABN12A8AE476C6' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMGIYR12AB0187973' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOQCGHN12AB0181246' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOHZMFE12A6D4FB412' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOUWEJS12AB01868A4' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOGSDHY12AB017BF39' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOJIJWG12AAF3B46C0' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOGLWGG12A6D4F8046' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOAOAHZ12A8C13AAF1' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOCHTHF12AB017E206' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOXQIUR12A8AE4654A' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOANQFY12AB0183239' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOILFUU12AB017C75F' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOQGSUC12A8C13B66D' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOZNLBZ12A6D4F639E' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOAKPMX12AB018193B' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SODQZCY12A6D4F9D11' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOONOZO12AC3DF6CC4' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMTVRZ12A8C13A987' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOQQXKG12A6701C4D6' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOODSPH12AB01819C3' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOWCKVR12A8C142411' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOUNJIO12AB0181339' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOCIHMS12A8C142CC7' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMGVYU12A8C1314FF' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOUBEXV12AB01804A4' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOMDVSL12A6D4F7230' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOJTJAU12A8C1395C4' '00000b722001882066dff9d2da8a775658053ea0']
#  ['SOLGLUC12AB018A8FA' '00000b722001882066dff9d2da8a775658053ea0']]
