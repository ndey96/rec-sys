# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import pandas as pd
from tqdm import tqdm
import numpy as np
import time

username = 'ndey96'
scope = 'user-top-read'
token = util.prompt_for_user_token(username,
                                   scope,
                                   client_id='02c386b9bcfb43248ad7011c576c1e3f',
                                   client_secret='f2406ab918d349689325d2f6916aa656',
                                   redirect_uri='http://localhost:8888')
sp = spotipy.Spotify(auth=token)
sp.trace = False
time_range = 'long_term'
tracks_pt1 = sp.current_user_top_tracks(time_range=time_range,
                                     limit=50,
                                     offset=0)['items']
tracks_pt2 = sp.current_user_top_tracks(time_range=time_range,
                                     limit=50,
                                     offset=49)['items']
tracks = tracks_pt1 + tracks_pt2[1:]
for i, track in enumerate(tracks):
    print(i, track['name'], '//', track['artists'][0]['name'])
# Out:
# 0 Five Hours // Deorro
# 1 Come Down // Anderson .Paak
# 2 Sultans Of Swing // Dire Straits
# 3 Wesley's Theory // Kendrick Lamar
# 4 Backseat Freestyle // Kendrick Lamar
# 5 Cold Little Heart - Radio Edit // Michael Kiwanuka
# 6 Footsteps in the Dark, Pts. 1 & 2 // The Isley Brothers
# 7 The Bottle // Gill Scott
# 8 Feasting on the Flowers // Red Hot Chili Peppers
# 9 Sweet Emotion - Montmartre Remix // The Kooks
# 10 Dangerous - Sebu Remix // Big Data
# 11 Helicopter // Bloc Party
# 12 All Night (feat. Knox Fortune) // Chance the Rapper
# 13 School // Calvin Harris
# 14 Kalahari // Take/Five
# 15 IV. Sweatpants // Childish Gambino
# 16 Redbone // Childish Gambino
# 17 Sucker for Love // Cherub
# 18 Dear Neighbor (feat. Jenni Potts) - Pham Remix // Flapo
# 19 Canned Heat // Jamiroquai
# 20 King Kunta // Kendrick Lamar
# 21 Learn to Trust // Bad Suns
# 22 The Less I Know The Better // Tame Impala
# 23 I Love My Friends // Foster The People
# 24 The City // Anderson .Paak
# 25 Goodbye Angels // Red Hot Chili Peppers
# 26 City Of Stars - From "La La Land" Soundtrack/Pier // Ryan Gosling
# 27 Put Me Thru // Anderson .Paak
# 28 Let It Happen // Tame Impala
# 29 Hip Hop // Mos Def
# 30 Doncamatic - feat. Daley // Gorillaz
# 31 Can't Hold Us - feat. Ray Dalton // Macklemore & Ryan Lewis
# 32 Trouble // Cage The Elephant
# 33 m.A.A.d city // Kendrick Lamar
# 34 Dark Necessities // Red Hot Chili Peppers
# 35 Snow (Hey Oh) // Red Hot Chili Peppers
# 36 i // Kendrick Lamar
# 37 Black Panda // Koi Child
# 38 ATM // J. Cole
# 39 Rich (feat. Anndreyah Vargas) - Radio Edit // Cosmo Sheldrake
# 40 Already // Anderson .Paak
# 41 The Seed (2.0) // The Roots
# 42 Booyah - Original Mix // Showtek
# 43 To the Top // Too Many Zooz
# 44 The Soundmaker // Rodrigo y Gabriela
# 45 Disco Inferno - Single Edit // The Trammps
# 46 Elbow Pain // Glue Trip
# 47 Can't Stop // Red Hot Chili Peppers
# 48 The Blacker The Berry // Kendrick Lamar
# 49 Boogie Wonderland // Earth, Wind & Fire
# 50 Good Feelin // Capitol 1212
# 51 The Adventures Of Rain Dance Maggie // Red Hot Chili Peppers
# 52 September // Earth, Wind & Fire
# 53 MK Ultra // Muse
# 54 We The People.... // A Tribe Called Quest
# 55 When You Were Young // The Killers
# 56 3005 // Childish Gambino
# 57 Genesis // Justice
# 58 Naive // The Kooks
# 59 Your Hand In Mine // Explosions In The Sky
# 60 B.Y.O.B. // System Of A Down
# 61 Alright // Kendrick Lamar
# 62 California Dreamin' - Single Version // The Mamas & The Papas
# 63 Strip My Mind // Red Hot Chili Peppers
# 64 DNA. // Kendrick Lamar
# 65 Tamacun // Rodrigo y Gabriela
# 66 Treasure // Bruno Mars
# 67 Diablo Rojo // Rodrigo y Gabriela
# 68 Lost in the Crowd (feat. Fashawn, Zion I) // Bassnectar
# 69 That Lady, Pts. 1 & 2 // The Isley Brothers
# 70 The Season | Carry Me // Anderson .Paak
# 71 Panda // Desiigner
# 72 Beside You // Phildel
# 73 Mansion // Calvin Harris
# 74 HUMBLE. // Kendrick Lamar
# 75 Am I Wrong // Anderson .Paak
# 76 Feel the Love (feat. Childish Gambino) - VIP Mix // Rudimental
# 77 Move on Up - Extended Version // Curtis Mayfield
# 78 Under The Bridge // Red Hot Chili Peppers
# 79 Little Black Submarines - radio edit // The Black Keys
# 80 GLOWED UP // KAYTRANADA
# 81 Villuminati // J. Cole
# 82 Stare // Prince
# 83 Full Clip // Gang Starr
# 84 Vultures // John Mayer
# 85 Me and Your Mama // Childish Gambino
# 86 Mia & Sebastian’s Theme - From "La La Land" Soundtrack // Justin Hurwitz
# 87 Dani California // Red Hot Chili Peppers
# 88 Vikingman // Rodrigo y Gabriela
# 89 Say It Ain't So // Weezer
# 90 Good Times // CHIC
# 91 6 Summers // Anderson .Paak
# 92 Torito - Live from Spotify NYC // Rodrigo y Gabriela
# 93 Redbone // Childish Gambino
# 94 Time in a Bottle // Jim Croce
# 95 MC's Act Like They Don't Know // KRS-One
# 96 Two Words // Kanye West
# 97 untitled 07 | levitate // Kendrick Lamar
# 98 Get Up (I Feel Like Being A) Sex Machine - Pt. 1 & 2 // James Brown

# %%
sp_ids = [track['id'] for track in tracks]
sp_ids
# Out:
# ['6r7FXNO57mlZCBY6PXcZZT',
#  '276zciJ7Fg7Jk6Ta6QuLkp',
#  '37Tmv4NnfQeb0ZgUC4fOJj',
#  '7Ks4VCY1wFebnOdJrM13t6',
#  '3aGibUHhQyBsyumYHylw0K',
#  '7KX65PC1UZuImsUInThbav',
#  '1tL5a9jowsWMtn3wkFYsG9',
#  '5PRExK60JlWq8jybMNrj71',
#  '0SMzXgUFqcAt0WNCsGm3tM',
#  '4ORadZjMm6szG6mf0rBLXI',
#  '1GGAFSOcU7nMNLVKZwWyju',
#  '7vjzFWG4neQ9YYMN9yZ9hr',
#  '60xaS8mYBKUW4VQQ666N0T',
#  '47aTIe7m6ZFYTh3k3RWukF',
#  '6rDBRNVPEHVWUCkDrUVY5a',
#  '2rmq49FcJ4U3wh1Z7C9UxE',
#  '3kxfsdsCpFgN412fpnW85Y',
#  '3bpdzTbrMTVmhSCZIOnP0a',
#  '5WNTvu2nQ4RO6GUMRrj2kf',
#  '2u5woInaGB7YASEd1CwGBJ',
#  '0N3W5peJUQtI4eyR6GJT5O',
#  '6CubWHZakFiId6yMAzrRQN',
#  '6K4t31amVTZDgR3sKmwUJJ',
#  '4bMIRaesSZwIldFWCGs96S',
#  '35nTgQscqJHPc96HoRxfgt',
#  '2XTkpF9T2PKvcLgamGJGx1',
#  '5BMwpS4iYKR30kq9U9beaT',
#  '70SjyVMzhmMeJQD8hOmIBp',
#  '2X485T9Z5Ly0xyaghN73ed',
#  '4gQdwwPXSXnDkUh4jYqLoC',
#  '7twVmetQlugzgUqdMNjdJ4',
#  '3bidbhpOYeV4knp8AIu8Xn',
#  '5n0CTysih20NYdT2S0Wpe8',
#  '439TlnnznSiBbQbgXiBqAd',
#  '2oaK4JLVnmRGIO9ytBE1bt',
#  '2aibwv5hGXSgw7Yru8IYTO',
#  '3ODXRUPL44f04cCacwiCLC',
#  '0FHoQy4FLym4eVn6d2JCx0',
#  '2UciqgwVDwro0fev3MFbxJ',
#  '2ouDQcQR4aV33iXciWvWqk',
#  '0YOTE8vEGduSABT8QE55rK',
#  '1a6Jt6USVGKzbjYpcKMwPB',
#  '30BBwDTjwHQf1ixFGaE2o2',
#  '5UxbjTLzDV72IWWLzVLAiF',
#  '4qozE9YNw4RKITV5c2AF8A',
#  '22ff60cZy4APp7bzESHLR8',
#  '6WvESq4vEfCqsVCiWl5o8t',
#  '3ZOEytgrvLwQaqXreDs2Jx',
#  '5Mtt6tZSZA9cXTHGSGpyh0',
#  '6ztstiyZL6FXzh4aG46ZPD',
#  '1IXbpyIb2QbovU6kgyjW8U',
#  '0PgNhIg5n0UAOBVn43b8b6',
#  '5nNmj1cLH3r4aA4XDJ2bgY',
#  '0MrkZz4D3fGlEkhebjPPrh',
#  '3wUX7HpXS382s1DHTRouVk',
#  '70wYA8oYHoMzhRRkARoMhU',
#  '3Z2sglqDj1rDRMF5x0Sz2R',
#  '2W29TNaSCiolWbPfQNgNOW',
#  '7BHPGtpuuWWsvE7cCaMuEU',
#  '5NdxiycRi3nP2v7RJoAJIT',
#  '0EYOdF5FCkgOJJla8DI2Md',
#  '3iVcZ5G6tvkXZkZKlMpIUs',
#  '4s6LhHAV5SEsOV0lC2tjvJ',
#  '0J3ytriezGZ3KCREfHKDOI',
#  '6HZILIRieu8S0iqY8kIKhj',
#  '0XcDIyYZJ5L43fLBaTehz9',
#  '55h7vJchibLdUkxdlX3fK7',
#  '6NXt1wPncuJtYTpQbDD6eq',
#  '24pXGqFW7Ep5wbT9caFKYz',
#  '46pW0poQYEb2bVaqozGO59',
#  '5G0nSEIT0fGUZY0caM9AnH',
#  '275a9yzwGB6ncAW4SxY7q3',
#  '1lnv5XUK0gMv6gkU7URJR3',
#  '4GlFGnToMsIrjHx73i0dTz',
#  '7KXjTSCq5nL1LoYtL7XAwS',
#  '1UjyF6okUHhnVxaLV8ojsA',
#  '57497lKWyS9l3YUEGtWpkS',
#  '01gDLZsi0j5fWC28FLPNO8',
#  '3d9DChrdc6BOeFsbrZ3Is0',
#  '6ZWn1MVUaBH2HNQobhMYeE',
#  '0EXdB7xUEp2sxWHmofyi0n',
#  '3YjQfsV7vIDj0eovuUlbK7',
#  '2eZJ9lrNeSqDt9iOgtft0M',
#  '30oTS7bm0aH3p7lqjEIu8q',
#  '1IdTIzkTK6CcpKKgMUGbg7',
#  '4r0GVpjSsKSR1biv4fOoa5',
#  '1Vk4yRsz0iBzDiZEoFMQyv',
#  '10Nmj3JCNoMeBQ87uw5j8k',
#  '3okda1X50bg8aSCcNLa34s',
#  '4YPhn26bIFm2KUkL1VLzQG',
#  '0G3fbPbE1vGeABDEZF0jeG',
#  '0lG7iyNSstVOLV6faMIHdD',
#  '20L1HZEl7jTfqhx6HG4SWH',
#  '47l9wxr6RwgoTSfnseBRcf',
#  '5V9C9hg4Cfr03TeEl38tzY',
#  '0snDRsjNRMJhm7SVja8l6J',
#  '6GI114RuBiRyc09NcXyU6y',
#  '6QvxTX9zvo4u7XhP9vOP3n',
#  '7tMCIOFe99cWEYr21wfsDp']

# %%
msd = pd.read_hdf('data/full_msd_with_audio_features.h5', key='df')
# msd.shape
# msd[['spotify_id', 'danceability']].head()
# msd['spotify_id'] = msd['spotify_id'].astype(str)
# msd.columns

msd[msd['spotify_id'].isin(sp_ids)].head()

# msd = pd.read_hdf('data/full_msd_with_audio_features.h5', key='df')
# msd = msd[['song_id'] + embedding_cols]
# msd['song_id'] = msd['song_id'].astype(str)

# triplets = pd.read_hdf('data/triplets.h5')
# triplets['song_id'] = triplets['song_id'].str.encode('utf-8')
# triplets['song_id'] = triplets['song_id'].astype(str)
# Out:
# Empty DataFrame
# Columns: [artist_mbid, artist_name, artist_playmeid, release, release_7digitalid, song_hotttnesss, song_id, title, track_7digitalid, track_id, year, spotify_id, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence]
# Index: []
#
# [0 rows x 25 columns]
