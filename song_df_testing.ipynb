# %%
import pandas as pd

song_df = pd.read_hdf('data/song_df.h5', key='df')

# %%
song_df.head()
# Out:
#   sparse_index             song_id  year  acousticness  danceability  \
# 0         4785  SOAKIMP12A8C130995     0      0.656000         0.486
# 1         7052  SOAPDEY12A81C210A9  1974      0.588000         0.809
# 2        14453  SOBFOVM12A58A7D494     0      0.000111         0.598
# 3        20354  SOBSUJE12A6D4F8CF5  2006      0.119000         0.607
# 4        21408  SOBVFZR12A6D4F8AE3  2002      0.172000         0.722
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       112680   0.231          0.577000    7     0.128   -15.423     1
# 1       156200   0.831          0.013500    9     0.197    -4.027     0
# 2       141440   0.760          0.244000    7     0.101    -7.372     0
# 3       246410   0.504          0.000412    0     0.102    -8.176     0
# 4       171173   0.501          0.534000    1     0.119   -10.620     0
#
#    speechiness    tempo  time_signature  valence
# 0       0.0445  123.685               4   0.3890
# ...
