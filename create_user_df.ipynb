# %%
import pandas as pd
import numpy as np
import time
from scipy.spatial.distance import pdist
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from multiprocessing import Pool

# %%
embedding_cols = [
#     'year',
    'acousticness',
    'danceability',
    'duration_ms',
    'energy',
    'instrumentalness',
    'key',
    'liveness',
    'loudness',
    'mode',
    'speechiness',
    'tempo',
    'time_signature',
    'valence'
]

msd = pd.read_hdf('data/full_msd_with_audio_features.h5', key='df')[['song_id'] + embedding_cols]
msd['song_id'] = msd['song_id'].astype(str)

# triplets = pd.read_hdf('data/triplets.h5')

train_partial_data = pd.read_csv('data/train_triplets.txt', sep='\t', names=['user_id', 'song_id', 'play_count'])
train_full_data = pd.read_csv('data/EvalDataYear1MSDWebsite/year1_test_triplets_visible.txt', sep='\t', names=['user_id', 'song_id', 'play_count'])
# test_partial_data = pd.read_csv('data/EvalDataYear1MSDWebsite/year1_test_triplets_hidden.txt', sep='\t', names=['user_id', 'song_id', 'play_count'])

train_partial_data['is_test'] = False
train_full_data['is_test'] = True

triplets = train_partial_data.append(train_full_data, ignore_index=True)
triplets['song_id'] = triplets['song_id'].str.encode('utf-8')
triplets['song_id'] = triplets['song_id'].astype(str)

# %%
msd.head()
# Out:
#                  song_id  acousticness  danceability  duration_ms  energy  \
# 0  b'SOSIYAD12A8C14097F'        0.0142         0.471       254537   0.910
# 1  b'SOHPHTP12A8C13BF53'        0.8430         0.479       162173   0.315
# 2  b'SOFVVGL12A8C13C32F'        0.3070         0.678       188493   0.787
# 3  b'SOHXIRQ12AAA15CF81'        0.1470         0.804       278600   0.676
# 4  b'SOJHDEN12AB018B650'        0.1290         0.604       267200   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.764000    7    0.4030    -4.847     1       0.1090  175.816
# 1          0.000004    9    0.0911   -12.951     0       0.0991   97.886
# 2          0.000080    9    0.7140    -6.344     1       0.0355  128.181
# 3          0.919000    3    0.0797    -8.480     0       0.0437   94.994
# 4          0.000000   11    0.1850    -4.419     0       0.0507  124.088
#
#    time_signature  valence
# 0               4    0.282
# 1               4    0.309
# 2               4    0.969
# 3               4    0.527
# 4               4    0.399

# %%
triplets.head()
# Out:
#                                     user_id                song_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOAKIMP12A8C130995'
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOAPDEY12A81C210A9'
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOBBMDR12A8C13253B'
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOBFNSP12AF72A0E22'
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOBFOVM12A58A7D494'
#
#    play_count  is_test
# 0           1    False
# 1           1    False
# 2           2    False
# 3           1    False
# 4           1    False

# %%
triplets.shape
# Out:
# (49693480, 4)

# %%
niplets = triplets.merge(msd, left_on='song_id', right_on='song_id')
niplets.head()
# Out:
#                                     user_id                song_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  b'SOAKIMP12A8C130995'
# 1  7c86176941718984fed11b7c0674ff04c029b480  b'SOAKIMP12A8C130995'
# 2  76235885b32c4e8c82760c340dc54f9b608d7d7e  b'SOAKIMP12A8C130995'
# 3  250c0fa2a77bc6695046e7c47882ecd85c42d748  b'SOAKIMP12A8C130995'
# 4  3f73f44560e822344b0fb7c6b463869743eb9860  b'SOAKIMP12A8C130995'
#
#    play_count  is_test  acousticness  danceability  duration_ms  energy  \
# 0           1    False         0.656         0.486       112680   0.231
# 1           1    False         0.656         0.486       112680   0.231
# 2           3    False         0.656         0.486       112680   0.231
# 3           1    False         0.656         0.486       112680   0.231
# 4           6    False         0.656         0.486       112680   0.231
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.577    7     0.128   -15.423     1       0.0445  123.685
# 1             0.577    7     0.128   -15.423     1       0.0445  123.685
# 2             0.577    7     0.128   -15.423     1       0.0445  123.685
# 3             0.577    7     0.128   -15.423     1       0.0445  123.685
# 4             0.577    7     0.128   -15.423     1       0.0445  123.685
#
#    time_signature  valence
# 0               4    0.389
# 1               4    0.389
# 2               4    0.389
# 3               4    0.389
# 4               4    0.389

# %%
niplets.shape
# Out:
# (20107787, 17)

# %%
# Using multiprocessing.Pool.map and play_count weightings
# LET n = number of songs
# LET m = number of audio features

feature_MUSIC_dict = {
    'danceability': np.array([-0.37, 0.05, -0.35, 0.08, 0.43]),
    'energy': np.array([-0.64, -0.46, -0.13, 0.66, -0.03]),
    'instrumentalness': np.array([0.20, -0.47, 0.28, 0.09, -0.01]),
    'liveness': np.array([-0.69, -0.12, -0.07, 0.43, 0.02]),
    'loudness': np.array([-0.58, -0.19, -0.44, 0.79, -0.21]),
    'valence': np.array([-0.04, 0.18, 0.24, -0.34, 0.18]),
}
# feature_MUSIC_matrix -> m x 5 matrix, where m is the number of audio features in feature_MUSIC_dict
feature_MUSIC_matrix = [MUSIC for MUSIC in feature_MUSIC_dict.values()]

# TODO: use play counts and scale song_vectors before calculating pdist
def get_cosine_list_dissimilarity(sub_df):
    # song_vectors -> n x m matrix, where m is the number of audio features in the embedding_cols
    song_vectors = sub_df[embedding_cols].values
    if len(song_vectors) == 1:
        return None
    return np.mean(pdist(song_vectors, 'cosine'))

def get_MUSIC(sub_df):
    # song_vectors -> n x m matrix, where m is the number of audio features in feature_MUSIC_dict
    song_vectors = sub_df[list(feature_MUSIC_dict.keys())].values
    
    # unweighted_MUSIC_vals -> n x 5 matrix
    unweighted_MUSIC_vals = song_vectors @ feature_MUSIC_matrix
    
    # returns the average MUSIC values weighted by their play_counts
    return list(np.average(unweighted_MUSIC_vals, weights=sub_df['play_count'].values, axis=0))

def get_is_test(sub_df):
    return sub_df['is_test'].values[0]

def get_song_ids(sub_df):
    # this is because each song_id looks like this: "b'SOSIYAD12A8C14097F'" 
    return [song_id_str[2:-1] for song_id_str in sub_df['song_id'].to_list()]

start = time.time()
gb = niplets.groupby('user_id')

def get_row(gb_item):
    user_id, sub_df = gb_item
    return {
        'user_id': user_id,
        'MUSIC': get_MUSIC(sub_df),
        'num_songs': sub_df.shape[0],
        'is_test': get_is_test(sub_df),
        'song_ids': get_song_ids(sub_df)
    }
    
data = Pool().map(func=get_row, iterable=list(gb), chunksize=625)
df = pd.DataFrame(data)
# print(time.time()-start)
df.head()
# Out:
#                                                MUSIC  is_test  num_songs  \
# 0  [4.229812033333332, 1.4042373883333334, 3.7184...    False          3
# 1  [4.910766939999999, 1.6201183160000001, 4.2151...    False          6
# 2  [3.9929606913333338, 1.3756423253666668, 3.569...    False          6
# 3  [4.160212249999999, 1.38550505, 3.48416005, -6...    False          3
# 4  [5.020851199999999, 1.2992664299999999, 4.2901...    False          9
#
#                                             song_ids  \
# 0  [SOBSSGK12A6D4F9EF1, SOCZQCY12AC468E40F, SOCTX...
# 1  [SOFXSRW12A6D4F3B77, SOFFWTH12A6310D9E8, SOLOD...
# 2  [SOBYRTY12AB0181EDB, SOYWZXA12A8C138274, SOYFP...
# 3  [SOBDRND12A8C13FD08, SODRFRJ12A8C144167, SOMMJ...
# 4  [SOBMSCQ12AAF3B51B7, SOJERWB12A8C13E654, SOMCH...
#
#                                     user_id
# 0  00000b722001882066dff9d2da8a775658053ea0
# 1  00001638d6189236866af9bbf309ae6c2347ffdc
# 2  0000175652312d12576d9e6b84f600caa24c4715
# 3  00001cf0dce3fb22b0df0f3a1d9cd21e38385372
# 4  0000267bde1b3a70ea75cf2b2d216cb828e3202b

# %%
df.shape
# Out:
# (1107613, 4)

# %%
df.to_hdf('data/user_df.h5', key='df', mode='w')
# Out:
# /Users/nolandey/anaconda/envs/tensorflow3/lib/python3.6/site-packages/pandas/core/generic.py:2378: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['MUSIC', 'user_id']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %% [markdown]
# # Garbage/Test Code

# %%
# using pandas groupby agg

def get_cosine_list_dissimilarity(song_ids):
    song_vectors = msd.loc[msd['song_id'].isin(song_ids)][embedding_cols].values
    if len(song_vectors) == 1:
        return None
    return np.mean(pdist(song_vectors, 'cosine'))

def get_MUSIC(song_ids):
    song_vectors = msd.loc[msd['song_id'].isin(song_ids)][list(feature_MUSIC_dict.keys())].values
    return list(np.mean(np.dot(song_vectors, feature_MUSIC_matrix), axis=0))

def num_songs(song_ids):
    return len(song_ids)

start = time.time()
gb = triplets.head(50000).groupby('user_id')
df = gb.agg([get_cosine_list_dissimilarity, get_MUSIC, 'count'])
df.columns = df.columns.droplevel(0)
df = df.dropna() # Removes all users who only listened to 1 song
df = df.reset_index()
df = df.rename(index=str, columns={
    "get_cosine_list_dissimilarity": "cosine_dissim",
    "get_MUSIC": "MUSIC",
    "count": "num_songs",
})
df['div_pref'] = StandardScaler().fit_transform(df['cosine_dissim'].values.reshape(-1,1))/2 + 0.5
print(time.time()-start)
# Out:
# /Users/nolandey/anaconda/envs/tensorflow3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/nolandey/anaconda/envs/tensorflow3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/nolandey/anaconda/envs/tensorflow3/lib/python3.6/site-packages/numpy/core/_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# 62.2878041267395

# %%
yolo = pd.DataFrame([{'a': True}])
yolo['b'] = False
yolo
# Out:
#       a      b
# 0  True  False

# %%
# yolo = msd.head()
# yolo
# print(yolo['song_id'].to_list())
# print(yolo['song_id'].str[2:-1].to_list())
# yolo
# yolo['song_id']
# print([song_id_str[2:-1] for song_id_str in yolo['song_id'].to_list()])
# Out:
#         song_id  acousticness  danceability  duration_ms  energy  \
# 0  YAD12A8C1409        0.0142         0.471       254537   0.910
# 1  HTP12A8C13BF        0.8430         0.479       162173   0.315
# 2  VGL12A8C13C3        0.3070         0.678       188493   0.787
# 3  IRQ12AAA15CF        0.1470         0.804       278600   0.676
# 4  DEN12AB018B6        0.1290         0.604       267200   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.764000    7    0.4030    -4.847     1       0.1090  175.816
# 1          0.000004    9    0.0911   -12.951     0       0.0991   97.886
# 2          0.000080    9    0.7140    -6.344     1       0.0355  128.181
# 3          0.919000    3    0.0797    -8.480     0       0.0437   94.994
# 4          0.000000   11    0.1850    -4.419     0       0.0507  124.088
#
#    time_signature  valence
# 0               4    0.282
# 1               4    0.309
# 2               4    0.969
# 3               4    0.527
# 4               4    0.399

# %%
lol = pd.read_hdf('data/full_msd_with_audio_features.h5', key='df')[['song_id'] + embedding_cols]

[song_id_str[2:-1] for song_id_str in lol['song_id'].to_list()]
# Out:
# ['SOSIYAD12A8C14097F',
#  'SOHPHTP12A8C13BF53',
#  'SOFVVGL12A8C13C32F',
#  'SOHXIRQ12AAA15CF81',
#  'SOJHDEN12AB018B650',
#  'SONVBWO12AB0187B35',
#  'SOGLAKB12AB017DF39',
#  'SOTAQLI12A8C13CFD5',
#  'SOANPML12AB017D645',
#  'SOBYKSS12A58A7C17C',
#  'SOSJYVH12A8C1424B5',
#  'SOCMLQF12A8C145701',
#  'SOQCFUK12A8C142F17',
#  'SOJTODJ12AB018ADC2',
#  'SOKOCYW12AB0184A65',
#  'SOSHJEP12A6D4F5886',
#  'SOVOLSW12A6D4F8BE9',
#  'SODSWWL12AC9618263',
#  'SOHRSRU12A8C136D7A',
#  'SOFJOMT12A8C137393',
#  'SOFENSY12A6D4FB766',
#  'SOAZIKY12A6D4FB469',
#  'SOAWYTV12AB018A6E8',
#  'SOBGWYD12A6D4FD600',
#  'SOJEIKW12A6D4F762B',
#  'SOBMJHH12AB017DF32',
#  'SOPLLWC12A8C138B25',
#  'SOKIABX12A8C131124',
#  'SONKTHE12AB018246E',
#  'SOCNGSC12AB0187A7C',
#  'SOKLZDQ12A8C143D9D',
#  'SOPOTYN12AB0181CD4',
#  'SOJLZCA12A8C133112',
#  'SOGGERY12AB01837E9',
#  'SORTHCE12AB0182A78',
#  'SOWPNTP12AAF3B1D86',
#  'SORRXBN12A58A7C684',
#  'SOJAWBG12A8C137499',
#  'SOJAWBG12A8C137499',
#  'SOJAWBG12A8C137499',
#  'SOJAWBG12A8C137499',
#  'SOIDWYM12AB0187B62',
#  'SOAJJBD12A8C133D78',
#  'SOLCUIC12A6D4F3BF4',
#  'SOKNYFJ12AB018927C',
#  'SOGLARH12AB0181867',
#  'SOCBSYK12A6D4F6E57',
#  'SOEJLBM12AB0184AB4',
#  'SOFMYQF12A6D4F70DE',
#  'SODHEZC12AB0184B83',
#  'SOFTDQD12AB017D7E4',
#  'SOKLSJN12A6701F9C1',
#  'SOKKAQV12AB01848C3',
#  'SOEQPLI12A8C13C578',
#  'SOFRRAP12A6310DA36',
#  'SOYAWWB12A6D4FC4DE',
#  'SOTOYCC12A6D4FB473',
#  'SOIKZQB12A8C12FEF1',
#  'SOIPIJK12AB0182915',
#  'SOXKFWF12A8C13B3A8',
#  'SOLFETY12AB01826E2',
#  'SOVCGYT12A6D4F615C',
#  'SOJVEGX12A6D4F9D34',
#  'SOACNTF12AC468E6D7',
#  'SOJRUNC12AB0180DE1',
#  'SOZSHHJ12AAF3B3A0A',
#  'SOPJKSL12A8C133166',
#  'SOTDPYF12A8C138D05',
#  'SOKSTVD12A8C13576A',
#  'SOEIZLG12A8C133DBA',
#  'SOEOAJW12AB01805BF',
#  'SOAVYTW12AB018600F',
#  'SOCLAQB12AC9072F76',
#  'SODADLS12AF72A164F',
#  'SOEOWOP12AB0182FD5',
#  'SOFDMPC12AB01844F2',
#  'SOINHBA12AB018A4F6',
#  'SOMBTJT12A8AE48834',
#  'SOAVQAZ12A8C13496D',
#  'SOAVQAZ12A8C13496D',
#  'SOAVQAZ12A8C13496D',
#  'SOAVQAZ12A8C13496D',
#  'SOANERZ12A58A7DA7F',
#  'SOLWDJS12A6D4F6523',
#  'SOAFVFQ12AAA15FCF4',
#  'SOGVDMM12AB0182B29',
#  'SOSQRDY12AAF3B25BC',
#  'SORDCXM12AB018114F',
#  'SOAGYOP12AAF3B2356',
#  'SOGXXFK12AB01854C2',
#  'SOIUQLE12A8C1442CD',
#  'SOJTNHP12A58A78588',
#  'SOLYVOL12A8C13B632',
#  'SODWSFY12A8C13E536',
#  'SOAFJGN12AB0187B1C',
#  'SOUEWCA12AB01865B8',
#  'SOHTIYE12AC3DF9399',
#  'SOCUDRR12AB0181081',
#  'SOFOFVY12A8C137ADA',
#  'SOBQWQA12A8C145621',
#  'SOPSIOU12AB018130E',
#  'SOJPQQQ12A8C13428C',
#  'SOQRNZQ12AC468C624',
#  'SOCELUI12AC46874A1',
#  'SOOKPMD12AB018B172',
#  'SODYYNK12A6D4F83DB',
#  'SORODMH12A6D4F9063',
#  'SOHSROK12A8C1420C2',
#  'SOFOQKT12AB017C9C3',
#  'SOFHQIV12A6D4FA45F',
#  'SOQAUCD12A58A7A0D7',
#  'SOQEKZQ12A8C13BB7E',
#  'SOXABOA12AB0187A15',
#  'SOHGOTF12AB0185193',
#  'SODSFTT12AB017BBC2',
#  'SOAEHEV12A6D4FB3D1',
#  'SOKVYYS12A8C13B16F',
#  'SOMTPVE12A8C1330E9',
#  'SOUSTXH12A8C13F614',
#  'SOZBTOJ12A58A7C577',
#  'SODFZEH12A8AE47A05',
#  'SORZEVA12A6D4F996D',
#  'SOVESXE12AB0186427',
#  'SOKVCXY12AB0189366',
#  'SONHCZB12AB018384C',
#  'SOBYCXP12AF72A0F3C',
#  'SOWXBCI12A8C136922',
#  'SODHOXV12AB018BFF4',
#  'SOZJCBK12A8C139B14',
#  'SOWDRHE12A8C13545C',
#  'SOIIPMB12AC468B3CB',
#  'SOPBVYZ12AB0181F60',
#  'SOBVDHC12A81C1FEB5',
#  'SOEVVOI12A6D4F683B',
#  'SOFTMXE12AB018D088',
#  'SOIGEBP12A81C209DE',
#  'SOBGGVG12AB01879B2',
#  'SOEVTAS12A67ADE5BC',
#  'SODPIUE12A58A7EFE2',
#  'SORCLVO12A6D4F75A1',
#  'SODLEHR12A8C13229E',
#  'SOEYQYE12AB01864B9',
#  'SOCLSAL12AB0189B83',
#  'SOEDLCN12AAF3B2CED',
#  'SOEGBNM12AF729F1C5',
#  'SOHTIVJ12A8C137FB2',
#  'SOJEWYS12A6D4F851A',
#  'SOGLYXY12AAF3B5EA6',
#  'SOUHJTU12A8C137D09',
#  'SOCOTYH12A8C1325BD',
#  'SOBWVEM12AB0187D0D',
#  'SOCYSNE12A58A7D54E',
#  'SOLEDNX12AB01873FE',
#  'SOATBHT12AB0181BE0',
#  'SONGYPB12A58A78C8A',
#  'SONVDEZ12A8C1328BB',
#  'SOABQWB12A8C13B562',
#  'SOABCWQ12AB018BFAE',
#  'SORWCPS12AF72ABCAE',
#  'SOTVSXD12AB0186FFD',
#  'SOFZRBD12A8AE45908',
#  'SOMDRCT12A8C13D9C5',
#  'SOOPJHP12A6D4F9D6B',
#  'SOSAHET12A6D4F692E',
#  'SOIIOFE12AB018E395',
#  'SONFLOU12A8C13FA2E',
#  'SOBZJSO12A6D4FBE8F',
#  'SOHKJHV12AB017AC3C',
#  'SOQOFAU12A8C13D34E',
#  'SOQFPFQ12AB018B9A1',
#  'SONVBMS12A8C14188B',
#  'SONEVZN12A6D4F7DA0',
#  'SOFUMSC12A8C1323BA',
#  'SOAWOWZ12AF72A49DD',
#  'SOCZPLL12AAA15E6FE',
#  'SOLRSKO12AC3DFB193',
#  'SOLGSRV12A8C132E8F',
#  'SOVWBTC12A67AE2293',
#  'SOMCDFM12AC9609F69',
#  'SOWRSNQ12AB018602D',
#  'SOCJURJ12AC9074ECB',
#  'SOIYOWA12AAF3B2B15',
#  'SODLEWK12A58A785AB',
#  'SODLEWK12A58A785AB',
#  'SODLEWK12A58A785AB',
#  'SODLEWK12A58A785AB',
#  'SOJNPHR12A6D4F8672',
#  'SOGPMRR12AAF3B24DC',
#  'SOTSAJM12A6D4FA576',
#  'SOJJBBH12A8C141DE9',
#  'SODRCLY12A58A7CB03',
#  'SOKTIEE12AB017D613',
#  'SOPRXWA12A6310DF27',
#  'SOYXURK12AB018D0F7',
#  'SOHNGUA12AB018475A',
#  'SOMWETC12AB018A407',
#  'SOZTJLN12A8C1390A7',
#  'SONMKBQ12AB018C343',
#  'SOMCMBV12AB0184637',
#  'SOWKPYS12A6D4F7CB1',
#  'SOCNCNV12A8C13F807',
#  'SOGYDVO12A8C13D604',
#  'SOJCTJK12A6D4FBB2F',
#  'SOBDSCS12A8C13A2BF',
#  'SONIEED12AB0184DE6',
#  'SOIDKMK12A67AE0DD6',
#  'SOQQQPS12AB017FB1A',
#  'SOGWUBE12A6D4FBD80',
#  'SOFAPJK12AB017FD93',
#  'SOFAPJK12AB017FD93',
#  'SOFAPJK12AB017FD93',
#  'SOFAPJK12AB017FD93',
#  'SOCPPVB12A6BD4DAB3',
#  'SOINYKX12AB0180812',
#  'SOCEVGD12A679D7E8B',
#  'SOKUTZZ12A8AE48F7D',
#  'SONVZMU12A8C13CEDC',
#  'SOCVNOG12A8C136022',
#  'SONAGGS12AB0186C1E',
#  'SOWHUYJ12A8C139B57',
#  'SORBYLT12AB0187899',
#  'SOKGKXO12A6D223C13',
#  'SOFFSKF12A8C13EF7E',
#  'SOHRGXS12A8C145536',
#  'SOXHMMZ12A6D4FD508',
#  'SONJAIZ12A8C13E54F',
#  'SOTFBWQ12A6D4F790A',
#  'SOAZYFW12A8C1418F0',
#  'SODNGLS12A81C20FF9',
#  'SOCULMY12A8C142FB0',
#  'SOGUEGF12AB01866D2',
#  'SOAOUDT12AF72A2B37',
#  'SORVDIL12AB0180360',
#  'SOBBEGJ12A8C13D11C',
#  'SOCOMJB12A58A7F939',
#  'SOGSDJQ12AB018865B',
#  'SOJDPJK12AC468885E',
#  'SOESRFM12AB01831E7',
#  'SOVRJIT12AB018749D',
#  'SOXQLGK12A6D4F8B10',
#  'SOAOZOA12AB0186F94',
#  'SOBUSPA12A8C13C121',
#  'SOEVAJQ12A8C13C45F',
#  'SODVPFM12A6D4F7872',
#  'SOHZPVW12A6D4F867D',
#  'SOCNKJJ12AB01823D6',
#  'SOBNCQQ12AB018D283',
#  'SOHXRCQ12A6D4F7BBE',
#  'SORUFMM12A6701C513',
#  'SOERNMK12AAF3B515C',
#  'SOAIKZY12AB0184627',
#  'SOEYTKK12AB017E12C',
#  'SOEDGSU12AB0188E7E',
#  'SODIDPE12A8C13FC9D',
#  'SOEODDK12A81C21730',
#  'SODWQOP12A8C13FCA4',
#  'SOZMLHT12AB018B548',
#  'SODFFEQ12A58A785B8',
#  'SOOUPAK12AC468EB7D',
#  'SOPFVVZ12AB018482F',
#  'SOBFYQI12AB018AF26',
#  'SODTIZW12AB017FACE',
#  'SOTDIJH12A8C1433E8',
#  'SOGDBBH12A6D4F7B7E',
#  'SOSCEYK12A58A7DA4D',
#  'SOJLNZG12AC468DA06',
#  'SOCFWMW12AF72A0FD2',
#  'SOBGRAY12A8C13EB59',
#  'SOAAOWW12AB0182FC2',
#  'SODJEYT12AB0180D1F',
#  'SOSPAQW12A58A75619',
#  'SONKILN12A8C136DDC',
#  'SOOGCRO12A8C13C743',
#  'SOJGPSY12AB0185772',
#  'SOYMVIF12A8C142C49',
#  'SOCDWDA12AB018AA20',
#  'SOHCPQT12AC3DFB301',
#  'SOFAHQB12AB018340C',
#  'SOONMWZ12AAF3B5233',
#  'SOBVWDR12AB018EF4F',
#  'SOENBBO12AB01851C8',
#  'SODKUAV12AAF3B4704',
#  'SOLLIKF12A8C13732E',
#  'SONYVOQ12AC46887EC',
#  'SOOOKVA12A8C136581',
#  'SOIPGHT12A6701FBB5',
#  'SOCTPOH12A8C13E995',
#  'SOIVLDG12AB01824EE',
#  'SOGNAMQ12AB0183305',
#  'SORBTSJ12AB0182BB5',
#  'SOANBIK12A6D4F6020',
#  'SOGGEMF12AB0182E84',
#  'SOBXVTT12A8C13A767',
#  'SOGBHBH12AB01838A6',
#  'SOZHNOX12A8C13E439',
#  'SOSTQLL12AB017C698',
#  'SOEEGCT12A8C14154C',
#  'SOHMKKJ12AC3DF542E',
#  'SOJOTBC12AB017D3CE',
#  'SOIRHQJ12AB0187987',
#  'SOBMYMD12A8C13C4FD',
#  'SOZMPPP12A58A7C15E',
#  'SOFZJDC12A6D4F801B',
#  'SOANSOT12AB01879F9',
#  'SOTYJXR12A8C13393A',
#  'SOATQHV12AB0180381',
#  'SOFEVSD12A8C13DFAE',
#  'SOHRXAC12A8C13EBD6',
#  'SOKEPLI12A6D4FBB8E',
#  'SOCPTTH12A8C131683',
#  'SODVOSA12A8C13B233',
#  'SOHWNQT12A8C13D85E',
#  'SOSAENV12A8C1402A5',
#  'SOURJOZ12A6D4FC0C6',
#  'SOHHEAI12A8C139C2E',
#  'SOGTKKH12A6701F83E',
#  'SOGTKKH12A6701F83E',
#  'SOGTKKH12A6701F83E',
#  'SOGTKKH12A6701F83E',
#  'SOODOIG12A58A7B87D',
#  'SOABYYW12A67ADAF52',
#  'SOQWBQX12AB017D892',
#  'SONUEMJ12AB01809FD',
#  'SOYWWCM12AB018116F',
#  'SODBQAL12A6BD50E04',
#  'SOBRMZM12AB01888C1',
#  'SOUMMMR12AB017A590',
#  'SOAEUMI12AB0184C07',
#  'SOBSAJN12A8C134357',
#  'SOWKXUI12AB0181DDB',
#  'SOBNOPM12A8C1355F4',
#  'SOJMMSG12A6701D943',
#  'SOSSBKY12A6D4F8377',
#  'SOESHUQ12A6D4F624D',
#  'SOGIAZW12A58A7ADB1',
#  'SOPOSEH12AB017F451',
#  'SOILCUN12A8C13D97A',
#  'SOBKHRH12AC960DF13',
#  'SOLOBZN12AB0186F34',
#  'SOOKAAZ12A58A76F05',
#  'SOZBFGL12AB0183399',
#  'SOTXASD12A6D4FB8D9',
#  'SORICFT12A6D4F9C75',
#  'SOTJHTN12A8C13DD0F',
#  'SOBLEJS12A6D4FBF9D',
#  'SOCCECX12A6D4F855A',
#  'SOFHVKT12AC46856B7',
#  'SOEKDAL12AB01844DA',
#  'SOPVMMO12A6D4F7D50',
#  'SOKHUPY12AB0180B5E',
#  'SONYJPQ12A58A7C3D4',
#  'SOCHYCI12A8C13A966',
#  'SOATFNW12A8C133F62',
#  'SOOSZJZ12A6D4F4AA2',
#  'SOMRWRP12AB0183A04',
#  'SOPBWAQ12A8C1418D0',
#  'SOCOJJF12AB01848BF',
#  'SODOCYB12A8C13C093',
#  'SODHUUK12AB0182C54',
#  'SOUKXIZ12A8C136862',
#  'SOCIALK12A58A7551B',
#  'SOSDBEN12AC468C333',
#  'SOUDLWS12AB018C5AC',
#  'SOCLREZ12A8C1415D1',
#  'SOIJYAW12AB018AF8F',
#  'SOUFZFD12AB0183E0E',
#  'SOAJFFT12A8C13CF97',
#  'SOUOZVE12A8C1332C1',
#  'SORDYGF12AC468875A',
#  'SOMKOOF12A8C13AA2E',
#  'SOXFFAJ12AB0180254',
#  'SORTGLH12A8C138F7E',
#  'SOIDDCL12A8C139CDA',
#  'SOTEVOL12AB0183B74',
#  'SOBWXUE12A6D4F7EC7',
#  'SOEYPMG12A8C13EC0C',
#  'SOLBLRC12AB018BBD8',
#  'SODDOKA12A8C13D563',
#  'SOCRJIZ12A8C143B68',
#  'SODNWVT12A6D228288',
#  'SOPUJZD12AB017BAA8',
#  'SOWVCKW12A58A7A9FB',
#  'SOYHYIM12AB017FB14',
#  'SOEDOBI12A8AE45104',
#  'SOCJTYA12A6D4F652C',
#  'SOMKBCZ12AB018985B',
#  'SOFBCRC12A8C13CD23',
#  'SOHUEAZ12A8C13D37F',
#  'SOLIYGM12AB017F6EF',
#  'SOWILZA12AB018611C',
#  'SOKCNYM12AB0185AE6',
#  'SOKSNUQ12AB0182C49',
#  'SOKZCTC12AB01887C6',
#  'SOEAPQS12A58A786EA',
#  'SOAKXUU12AB01852CD',
#  'SOKKDOU12AB017D62B',
#  'SOCUTQP12AB01815B1',
#  'SORDYIR12A6701E88A',
#  'SOEKXPT12A6D4F76FB',
#  'SODQPFY12A8C13E62B',
#  'SOJIRST12A6D4F9B1A',
#  'SOFAICW12A8C13FF53',
#  'SOBZVOB12A6BD53D2F',
#  'SOAVOSQ12A58A7DC8C',
#  'SONJOCO12AAF3B46F8',
#  'SOHFUUU12AC90752AD',
#  'SOHMAUP12A6D4FB41A',
#  'SODLTYU12AB0182D68',
#  'SODHSPP12AF72AC4CC',
#  'SOCZZGX12AAF3B49F4',
#  'SOIIUXK12AB018B556',
#  'SOFABMJ12A8C13680C',
#  'SOQDLHO12AB017FA00',
#  'SONQQLT12A8C1344A6',
#  'SONZOGM12A6D4FAEF1',
#  'SOGHAXG12A8C13EF3D',
#  'SOLCZTZ12A58A7E109',
#  'SOATQYM12AB018062A',
#  'SOGXKWX12A8C141F4E',
#  'SOETZUY12A6D4F6600',
#  'SOCGUTO12AB018DB03',
#  'SOIYOYI12AC468A9D8',
#  'SOCCZDJ12A8C13D136',
#  'SOAVDEA12A6BD52A50',
#  'SORZJID12A58A7C41F',
#  'SORPWVM12AB018B728',
#  'SOVEEBH12AB01882E6',
#  'SOBHJCB12AB0182286',
#  'SOWSCGE12AB018DDF9',
#  'SOHVASA12AC4687B77',
#  'SOHKNVP12A8C141BE8',
#  'SOJSJCI12AB01883CD',
#  'SODBWZV12AB0188A9E',
#  'SOEIRPU12AB018493D',
#  'SOHDWKF12A6D4F92F5',
#  'SOCAIZS12A8C134581',
#  'SOMXTGC12AB0186887',
#  'SODFCYV12A582A2BF1',
#  'SONBNHQ12A58A7B357',
#  'SOUBSFV12A8C13DB1D',
#  'SOACLSK12A6D4FC276',
#  'SOKNAOF12AF72AC876',
#  'SOGTRKW12A8C131D38',
#  'SODZYHZ12AB0189A92',
#  'SOLOHAW12A8C13A9B3',
#  'SOMGDBT12A8C142A57',
#  'SOTWBYM12A8C139639',
#  'SOFNFTC12AB018A7A5',
#  'SOCKHPC12A8C131C88',
#  'SOGEIPD12AB017F30A',
#  'SOFBOTK12A8C13BB6D',
#  'SOKEEFL12A6D4F7B18',
#  'SOBPXMR12AAA8C6B79',
#  'SOAMVEK12A8C13B1EF',
#  'SOQUKKG12AB0182E79',
#  'SOYWNRS12A8C1361A2',
#  'SOBGTXG12A6D4F609F',
#  'SOGFDGI12A582A29DC',
#  'SOGFDGI12A582A29DC',
#  'SOGFDGI12A582A29DC',
#  'SOGFDGI12A582A29DC',
#  'SOFLKBN12A8C1335C6',
#  'SOMBJDA12A6D4FC348',
#  'SOCOYLA12AC960A30C',
#  'SOSAUWT12A6D4FA7DA',
#  'SOFCPJK12A8C1382F3',
#  'SOEATPR12AB017BF70',
#  'SONZWVS12A6D4F7DFD',
#  'SOYZRMT12A8C137A08',
#  'SOBQNRR12AB01853FF',
#  'SOJGAXA12A8C131B55',
#  'SOMVCKJ12A8C142BAA',
#  'SOULVXY12AB0185BC3',
#  'SOHSWVY12A8C13C404',
#  'SOEBMBQ12A8C140104',
#  'SODDETV12AB01801E0',
#  'SOWXICJ12A6D4F7D50',
#  'SODLDDK12A6D4FA16F',
#  'SOADKFM12A58A812E5',
#  'SOWCNBR12A6D4F69D7',
#  'SOVKDYH12AC468A6E3',
#  'SOANPNC12A8C1420D5',
#  'SOQBOUI12AB018C856',
#  'SORCTGV12A6701EB4C',
#  'SOFLWYY12A8C136E55',
#  'SOFMRFW12A6D4F6C7B',
#  'SOFQWGE12A8AE46CFD',
#  'SOIEKEH12AC9072E58',
#  'SOWPFJF12A8C13E0D9',
#  'SOAQEBB12A6D4FA8CF',
#  'SOAJEQO12A6D4FA3A4',
#  'SOKFKJZ12A8C1384D5',
#  'SODLQEE12AAF3B4C33',
#  'SOLYAWU12A8C13B10D',
#  'SOCUXNH12A8C143198',
#  'SOCUXNH12A8C143198',
#  'SOCUXNH12A8C143198',
#  'SOCUXNH12A8C143198',
#  'SOALQJK12A6D4FDA79',
#  'SOXRQDL12A8C13D79F',
#  'SOGBGNC12A8C1440C0',
#  'SOINJJK12AB018CBCB',
#  'SOUTQJN12A67ADE690',
#  'SOBCFJF12A8C13F015',
#  'SOLNVMY12A8C145267',
#  'SOCPQZZ12A81C20F76',
#  'SOKDIHJ12A8C131904',
#  'SOTTJWY12A8C1407C7',
#  'SOIOPSB12A8C141C79',
#  'SOHAMOF12A6D4F9C0E',
#  'SOUTGZN12A8C14071F',
#  'SOBITNM12AB017F107',
#  'SOFUPBD12AC960DE89',
#  'SOGTSWY12AC9E15DF5',
#  'SOLERBM12A6701F5E3',
#  'SOKJJXM12AC468C225',
#  'SOAQVAM12A8AE484A4',
#  'SOEZLWC12A8C13811D',
#  'SOOJQLO12A8C13ECE1',
#  'SOAMKDL12AB0184906',
#  'SONFYCR12A8AE45BAA',
#  'SOBQYZZ12A8C137B22',
#  'SOFNOTI12A8AE475F3',
#  'SOGYDBQ12AB01887CE',
#  'SOGXNDY12A8C13553A',
#  'SOKZRTD12A6D4F8C0D',
#  'SODWJAJ12A8C1370E1',
#  'SOCQMLK12A6D4FD789',
#  'SOADDVI12AB0185729',
#  'SOBDZNM12AB0182FAD',
#  'SOGCJCU12A8C13F263',
#  'SOJDXSK12AB0184604',
#  'SODANVW12A8AE47BE5',
#  'SOGLBFH12AAF3B4496',
#  'SOPQBJE12A81C221D9',
#  'SOEGHSW12A8C132171',
#  'SONLCQS12AC468CFFF',
#  'SOAMHCJ12A8C1423DA',
#  'SOPUQRN12AB018AF08',
#  'SOEXRWX12A6D4F97AF',
#  'SOAKHOX12A6D4F896C',
#  'SOSXCYI12AB0189921',
#  'SOKNPXP12A6D4FB4F0',
#  'SOYGZIC12A8AE471DE',
#  'SOCLSNU12AB018C904',
#  'SOFICSA12A8C13CE9F',
#  'SOFDZNQ12A8C130CBF',
#  'SODVJFT12AB01842EE',
#  'SOBXBUX12A8AE47194',
#  'SONNQCO12A6D4F620D',
#  'SOQVJYA12AB0181BF3',
#  'SOBUQPJ12AB0184958',
#  'SOECNZO12AB017DE4E',
#  'SONGUDU12AC4687F41',
#  'SONRAIV12A67ADD68C',
#  'SOCCEKD12AC468569A',
#  'SOCBFZP12AB01864C5',
#  'SOAIWDV12AC3DFB02C',
#  'SOCMLXV12A58A7A4BE',
#  'SOJTSOG12A8C13D673',
#  'SOBGLXV12AB0183326',
#  'SODXAKM12A8C13F4A6',
#  'SOAHCRI12A6D4F9AC5',
#  'SONEONN12AB018BBE7',
#  'SOHSVDI12AB017F5B6',
#  'SONUBTM12A8AE46B59',
#  'SOQNQES12AB0185492',
#  'SOGGFOL12AAFF4295C',
#  'SOHMGHS12AB018B95B',
#  'SOYEQLD12AB017C713',
#  'SOBETNR12AB0184216',
#  'SOCZVXI12A58A7A32B',
#  'SOCGOKB12A58A7F40E',
#  'SONNUHU12A8C139F57',
#  'SOUNJLO12AB0189DD3',
#  'SOHAZQL12AB01802A4',
#  'SOALKEM12AB0181B54',
#  'SOJXONK12AB018266E',
#  'SOAWDYI12A8C13C923',
#  'SODCHOD12A58A81816',
#  'SOGWLJZ12A8C136502',
#  'SOKFUJB12A8C132F3B',
#  'SOALNPF12A58A7C324',
#  'SODLRYF12AC9097A58',
#  'SOCLQMO12A6D4F6AE8',
#  'SOHGPMS12A67020935',
#  'SOBGWDO12AAF3B3F68',
#  'SOYWXTO12A6310D881',
#  'SOHSPWG12A8C136711',
#  'SOXDMPE12AB0184170',
#  'SOAWNJD12AB017AFD9',
#  'SOYHYPV12A6D4FC706',
#  'SOBITAC12AB0187103',
#  'SOVFNSE12A8C140A83',
#  'SOZZBQZ12A8C13E184',
#  'SOKRQPU12A8AE4683A',
#  'SOCZCFS12AB018163C',
#  'SOMEEMB12AC4689096',
#  'SOCYCCE12A6D4FC404',
#  'SODZKWC12AF72A3B0A',
#  'SOHTDNL12A8C142E08',
#  'SOGNKGW12AB018650E',
#  'SOBPQTJ12AB0183A8E',
#  'SOWAADA12AB01824EB',
#  'SOBNSBU12A6D4FA8F0',
#  'SOIOYRZ12A58A77CB3',
#  'SOOHPVI12A8C13EE98',
#  'SOJCCTO12A58A78B98',
#  'SOJYWLM12A8C13A271',
#  'SOHUWAM12A8C140501',
#  'SOXVRBJ12AB01840A4',
#  'SOEZPWQ12AC468D1A6',
#  'SOUOYOW12A6D4FD716',
#  'SOLLMPZ12AC3DF6BA7',
#  'SOHAEVC12AB0188D3A',
#  'SOLGMBZ12A6D4FA365',
#  'SOCLUQR12A8C13FEFF',
#  'SOCLUQR12A8C13FEFF',
#  'SOCLUQR12A8C13FEFF',
#  'SOCLUQR12A8C13FEFF',
#  'SOUYKTJ12AC468AB0F',
#  'SOEJMDR12AB018558D',
#  'SOJSQSZ12A6D4FA83B',
#  'SOESMLS12A8C1323B6',
#  'SOQBABN12A6D4F7952',
#  'SOCCLDI12AF72A71A3',
#  'SOBHFZL12AC468A29F',
#  'SODPVTW12AB0187C29',
#  'SOEJQGO12AB01826C6',
#  'SOTBOJR12AB017D594',
#  'SOKUTBF12AC3DF5E81',
#  'SOBYKSK12AB01821F5',
#  'SOCITXX12A58A7979C',
#  'SODNYCH12AB01894DA',
#  'SOFWSWH12A8C14456F',
#  'SOFWSWH12A8C14456F',
#  'SOFWSWH12A8C14456F',
#  'SOFWSWH12A8C14456F',
#  'SOVHUJQ12A8C1353C0',
#  'SOAZWLG12A67ADCDF0',
#  'SOBYHGZ12A8C13A46E',
#  'SOCXVLB12AB0181DCC',
#  'SORTXQL12AB0188A53',
#  'SOIYNVO12A6D4F90EA',
#  'SOAKAPO12AB018BD6B',
#  'SOPIHSY12AB0189F7A',
#  'SOIMCUD12AB018E66B',
#  'SOAVOZK12A8C13D65A',
#  'SOPCKTP12AB0183EE5',
#  'SOGBJHS12AB0182460',
#  'SOGTEAV12A58A7CF10',
#  'SOEBZQX12A8C13D28E',
#  'SOIKZNE12A8C13C276',
#  'SOAOGXH12A58A77456',
#  'SODKJIL12AC9075ABA',
#  'SOBPNWK12AC468E50F',
#  'SOMBTYI12AB0180431',
#  'SOOYADG12A8C134530',
#  'SOGXLZJ12AC9072D2C',
#  'SODMWSM12AB018452B',
#  'SONYCSB12A6701E5C4',
#  'SOQUBHL12AB018540D',
#  'SOJVYIX12A8C135778',
#  'SOEMFIQ12A8C14571B',
#  'SOSQNNV12AC3DF59FE',
#  'SOAYMVE12A6D4FADA9',
#  'SOANLVR12AB018E241',
#  'SORKTWG12A58A79C61',
#  'SOQSFHW12AAF3B233F',
#  'SOANKUH12A8C13DB74',
#  'SONTBQB12A8C140728',
#  'SOCZUTU12A670218FF',
#  'SOIMXOX12A8C1447F7',
#  'SOCCSCU12A8C138F4E',
#  'SOOFNSM12AB018191A',
#  'SODFMWA12A8AE49A79',
#  'SOJAPLX12A8C13284B',
#  'SOHWKZQ12AB01857EF',
#  'SONJCQP12AB0184A62',
#  'SOQDQTP12A8AE46ABD',
#  'SODEKCD12A6D4F7E9F',
#  'SODGNQZ12A81C238FA',
#  'SOSMELX12A6D4F8981',
#  'SOTUQNV12AB01866D5',
#  'SONJYOJ12A8C13D495',
#  'SOSFGEN12A8C13F17F',
#  'SOHWVUL12AC468B288',
#  'SOTHJXP12AB0183A92',
#  'SOJBMCI12A8C1399B0',
#  'SOHBVWB12A8C13748F',
#  'SOCJNHP12AAF3B4649',
#  'SOIDAUO12A8C131B66',
#  'SONHMSF12AB018537B',
#  'SOSLBUI12A8C141454',
#  'SOGGXZL12AC3DF9840',
#  'SOPSPGM12A8AE4798F',
#  'SODMBND12A8C1419FB',
#  'SOLGTQP12AB017D0D4',
#  'SOJWPWE12A8C143A50',
#  'SOCSDRB12A58A7FE91',
#  'SOFYHGV12A6D4FA8E3',
#  'SOYVZFV12A6D4F6E47',
#  'SOOYARP12AB01834D2',
#  'SOHQJHK12A8C13D478',
#  'SOLPSXS12AB017D1D2',
#  'SOLIXYO12A6D4F9812',
#  'SOSMMIX12AC4689B68',
#  'SOCEECG12A8C13D048',
#  'SONFRCL12AB01845FE',
#  'SOFBQYO12A6D4F8ADA',
#  'SOMECBT12A670204AF',
#  'SOAWUFD12AB017D532',
#  'SOCGSRB12AB0183785',
#  'SOAKWAP12A8C13F09A',
#  'SOVTPKV12A8C137099',
#  'SOWGXQZ12AB017F382',
#  'SOFBFTF12A8C13898F',
#  'SOPSSCN12A6D4F94D4',
#  'SOCKFQG12A8C13B6E3',
#  'SOEOBDM12A58A76592',
#  'SODHIPM12A6D4F556A',
#  'SOKRZUB12A8C1356D6',
#  'SOWBFXL12AB0181A82',
#  'SOFLFFS12AB0180E03',
#  'SOKWCOE12A6D4FD747',
#  'SOFNTPR12A8C142D4C',
#  'SOKUHMT12A6D4FB562',
#  'SOAUJDD12A8C12FA83',
#  'SOEJYPC12AC4688779',
#  'SOUUURA12A8C136341',
#  'SOGDHIF12AB018727E',
#  'SOAQYCS12A8C13ACEC',
#  'SOAAFXG12AB0185EB7',
#  'SODXVKG12A8C13431B',
#  'SOPENNI12A8C137242',
#  'SOZJVJR12AAA15D97D',
#  'SORBZQD12A8C140910',
#  'SONTAVS12AAF3B15FF',
#  'SOGNJQG12A8C13CA53',
#  'SOTNJPW12A8C14037D',
#  'SOIOWAL12A8C1391D3',
#  'SOXUQTF12A6D4FBC99',
#  'SODBUMY12A8C143924',
#  'SOPIWCE12A8C1348AE',
#  'SOAHKMI12AC9618464',
#  'SODNJAI12A8C1395C2',
#  'SOJBTZW12AB018CE0F',
#  'SOQFLOF12A8C1356EB',
#  'SORKBPP12A6D4FB5E9',
#  'SOBHOUP12A8C13B2EB',
#  'SOBGHGR12A8AE48988',
#  'SORJIJZ12AB01829D0',
#  'SOVJKOC12A8AE4606F',
#  'SOBUKAO12A6D4FB0C9',
#  'SOATMKV12A8C1376B2',
#  'SOCHYRX12AB0184C23',
#  'SOAPDYH12AB0180D9E',
#  'SOHAVRU12AB018431A',
#  'SOBHZKK12A6D4FB02F',
#  'SOBRJAT12A8C13EC0A',
#  'SOIXYXS12AB01867A3',
#  'SOGSMPL12AB018C2F7',
#  'SOGSMPL12AB018C2F7',
#  'SOGSMPL12AB018C2F7',
#  'SOGSMPL12AB018C2F7',
#  'SOMKRJJ12AB017FD06',
#  'SODVFQL12A8C13FEE3',
#  'SOEVOEF12A8C137219',
#  'SOVOYJR12A8C130C30',
#  'SOCTXBQ12AB0185F5E',
#  'SOGOCBY12AB018A895',
#  'SOCMHYA12A6D4F9960',
#  'SOHPLYK12A6D4F5F1A',
#  'SORAFRG12AB0182535',
#  'SOBIUHK12A8C13C17B',
#  'SOMBAQW12AB018CE0B',
#  'SOIRWWL12AB0187AC1',
#  'SOESVWW12AB0180C64',
#  'SOIAPNJ12A8C13A1FD',
#  'SODFXZF12AC3DF992F',
#  'SODJQFK12AB0189AAB',
#  'SOATNUH12AB017DF42',
#  'SOLYQVM12A58A7BE89',
#  'SOBNKUQ12A8C13CE9F',
#  'SOBFONG12A6D4FB55C',
#  'SOFBLHF12A8C13B748',
#  'SOBGZJA12AB018589D',
#  'SOAEUEG12AB0182839',
#  'SOGUPFB12AAA8C8632',
#  'SOGUPFB12AAA8C8632',
#  'SOGUPFB12AAA8C8632',
#  'SOGUPFB12AAA8C8632',
#  'SOFXBRE12AB0183E3D',
#  'SOEJIZH12A81C204FF',
#  'SOCYNAZ12A67020A3E',
#  'SOUTWIX12A8C13CF24',
#  'SOFXBLW12A8C140DB5',
#  'SOGZCVP12AB01828D4',
#  'SOCTVDT12AB0183029',
#  'SOJUKGP12A8C137BAB',
#  'SOPNKYW12AB0184452',
#  'SOEWZXD12AC3DF7167',
#  'SONNNXX12A6D4F9836',
#  'SOVYDEK12A6D4FA1FE',
#  'SOAITID12AB018742A',
#  'SOOEIKI12A6D4F85C0',
#  'SOHJEAP12A81C23025',
#  'SOPWMAI12AB01831C2',
#  'SOAAHMA12AB0187288',
#  'SOSLORV12A81C2309D',
#  'SOGQIMD12A6D4FA1E6',
#  'SOIQMKE12AF729F298',
#  'SOAXKYA12AB01897EF',
#  'SOWPVWF12AB017F7DD',
#  'SOGGXDF12AB0182CC5',
#  'SOAASKI12A8C13F19C',
#  'SOOTZOZ12A8C138428',
#  'SOVNDYA12A8C14185D',
#  'SOTXWMC12A8C13916D',
#  'SOVWLXW12AC3DFB04A',
#  'SODADXY12A6D4FC638',
#  'SOEUVMG12AB01868D9',
#  'SOMMUPF12AB018980F',
#  'SOFSHOD12A58A7947D',
#  'SOXWIKV12A8C1338A9',
#  'SONLDLU12A67ADF790',
#  'SOAOZUQ12AB017BA84',
#  'SOAHDSX12A8C135EB5',
#  'SOECTDN12AB018A494',
#  'SOJDMPN12A8C1424D4',
#  'SOTILYH12A58A79FF9',
#  'SOYYUNA12A8C139562',
#  'SOEJFGE12AB018207E',
#  'SOJVMIA12AB017FC3C',
#  'SOACKKG12A6D4FB5DA',
#  'SOJMWKI12A8C13816A',
#  'SOXOQOE12A8C13A14F',
#  'SOCLDMU12AB018A771',
#  'SOIGKLS12A6D4F8ED9',
#  'SOHBSOV12AB018D7CF',
#  'SOLVCIY12A8C13A834',
#  'SOIOOMU12A8C142CDF',
#  'SOVZFLH12AB018CA41',
#  'SOQJDER12AB017FDF0',
#  'SOGDBOQ12A8C13879D',
#  'SOAFSIK12AB018ADF3',
#  'SOKQMDO12AB017C340',
#  'SOMXFEH12A8C1437A0',
#  'SOVEOVI12AB018C447',
#  'SOQTJGA12AB01837BE',
#  'SOMSXQO12A8C13293F',
#  'SOEXYAX12A58A779F2',
#  'SOWUCHV12A6D4F99A8',
#  'SORMGYK12A8C136027',
#  'SOHJRPI12A8C13B38D',
#  'SOOXZFQ12AC468B142',
#  'SOBFXWQ12A8C1371EC',
#  'SOFLXKD12A8C140BEC',
#  'SONIZKL12A6D4FC45F',
#  'SODXYUR12A8AE484EE',
#  'SOKVJYU12A6D4FB232',
#  'SOLPFCA12A6D4FA82E',
#  'SOFPDDL12AB018909D',
#  'SOQTPQV12AC9097BE4',
#  'SOODVQE12A58A78C2E',
#  'SOCBDKI12A6D4FC58A',
#  'SORSKZP12AB0184566',
#  'SOIESLW12A6D4FA687',
#  'SOABJQJ12A8C138B20',
#  'SOMWSDO12AAF3B2A5F',
#  'SONVBIE12AB0189503',
#  'SOTGUII12A6D4F7F19',
#  'SOEQYXK12AB0181605',
#  'SOGITYG12AB0183066',
#  'SODWOBL12A8C13ADC8',
#  'SOUGPVV12AB0186397',
#  'SOIPFAE12AB017C3EA',
#  'SOZTHXM12A8C13FB86',
#  'SOFOHTT12A58A7A902',
#  'SOGTSBD12A8C13878D',
#  'SOASFRD12AB0181977',
#  'SODBGUY12AB017E009',
#  'SOJNTZR12AC468E40F',
#  'SOLDYFX12A81C1F7E3',
#  'SORTLVC12A6D4FCDFD',
#  'SOAAJFV12AB017B046',
#  'SOPPAHQ12AB017DD07',
#  'SODRKRC12AB017F09A',
#  'SOWMGUY12AB018569E',
#  'SOGUZJV12AC90752D6',
#  'SOJKXIK12A8C1461C0',
#  'SOJKXIK12A8C1461C0',
#  'SOJKXIK12A8C1461C0',
#  'SOJKXIK12A8C1461C0',
#  'SOHJLRN12A6701E995',
#  'SOLEFSH12A6310E921',
#  'SOJQTHO12A6D4FA692',
#  'SOVRHKH12AB0183575',
#  'SOLWWYY12A8AE4660F',
#  'SOMFGPW12A8C13D7CE',
#  'SOEHEJX12AC468D5A8',
#  'SOJLIXD12A6D4F46C6',
#  'SOLBMFL12A6D4FEE99',
#  'SOBNRIJ12AB0188C86',
#  'SOPZQNH12AB01841ED',
#  'SOGLZPU12AB01840A8',
#  'SOHFCRE12A6D4FBF8D',
#  'SOXFCAG12A8C1385BA',
#  'SOFYAQA12AB0184B17',
#  'SOXSYIW12AB01830E6',
#  'SOCALSR12A8C13C33B',
#  'SOYKCGR12AB01809EE',
#  'SODTLMU12A6D4F8410',
#  'SOCHGKC12AB01874B2',
#  'SORHSMM12A6D4F91BB',
#  'SOVZXLZ12AB0182EFB',
#  'SOECIEN12AB0185E21',
#  'SOPKJMD12A8C13975D',
#  'SOHKDEA12AB0187390',
#  'SOIHEIC12AB0181368',
#  'SOOGNOF12A8C1332AC',
#  'SOQMJHX12AC4686BEE',
#  'SOVSPUM12A8C1436AB',
#  'SOIMSEF12A58A7949A',
#  'SOCASYS12A8C13B46A',
#  'SOIMTWC12A6D4FAC86',
#  'SOASOOJ12A8C13BC5E',
#  'SOBLYLQ12AB0185440',
#  'SOKDPAQ12A8C13FB91',
#  'SOSATQV12AB018D8DF',
#  'SOBYNAP12A67020E1A',
#  'SOEIBXW12A58A77995',
#  'SOWFSMK12A6D4F796C',
#  'SOZVEQZ12A8AE47F0D',
#  'SOZDLDO12AB018BAB1',
#  'SOSAIBQ12A6D4F9021',
#  'SOOGQVP12AB0187F7C',
#  'SOITIHG12AB017FDCC',
#  'SOAYTDZ12AC468B4B2',
#  'SOMXDVK12A8C13195E',
#  'SORFNOP12A6D4FA9C7',
#  'SOLHZST12AB0180BAA',
#  'SOEJQRP12AC468D6BF',
#  'SOBMKOC12AB01844A1',
#  'SORHPKW12A8C1351E2',
#  'SOPOGKK12A8C140627',
#  'SOLRFFS12A8C13E0ED',
#  'SOKOPTH12A8C13A13C',
#  'SOIAPSK12A8C13B29A',
#  'SOADLDE12AB017F2AC',
#  'SOQXCVJ12A6D4FA5AF',
#  'SOFRRXL12A6310EC9F',
#  'SOENHYE12AC46872A2',
#  'SOGBVWP12A8C1384C8',
#  'SOETYJK12A8151CD9E',
#  'SOAXHEG12A67ADE947',
#  'SOQQFCC12AB01878E7',
#  'SOKRWXP12A8C13ED5F',
#  'SOALVKR12A8C133D47',
#  'SOEYIOL12A8C13A8A0',
#  'SODUUTW12A8C1330A9',
#  'SODSUCE129F0691954',
#  'SOSZTNE12A8C13B2F8',
#  'SOOZCEK12AB0183FF6',
#  'SODFWXE12A58A7830D',
#  'SODRGUL12A8C142C26',
#  'SOQGVFM12AB0180AA6',
#  'SOGMTYX12AB017F9BD',
#  'SONAUZC12AB01803F6',
#  'SOAZLJS12A6D4FE95B',
#  'SOMQQXF12AF72A72D0',
#  'SONTHAF12A6D4F8767',
#  'SODBTOK12A8C1367E0',
#  'SOMRKOG12A6D4F7899',
#  'SODCGJY12AB01882FC',
#  'SOLADKC12A8C136348',
#  'SONCJST12A6D4F7DF5',
#  'SODUALB12AAF3B2B74',
#  'SOHKGPD12AB0187F75',
#  'SOAFVNE12A6D4F87B1',
#  'SOGOWYQ12A8151AACE',
#  'SODZYBF12AAA8C4F76',
#  'SOIPORS12A8C137125',
#  'SOECUOZ12AB0186E48',
#  'SOZZSNP12A8C1325E1',
#  'SOFVZQX12A8C1417E1',
#  'SOFRCAC12A58A7DC56',
#  'SOCVMVB12A81C235DC',
#  'SOGGKXP12AC468BAEB',
#  'SOCNUAK12A6D4F9A42',
#  'SOARQCO12AB01819C5',
#  'SOIDERS12A8C139527',
#  'SOARGWR12A6D4F8E89',
#  'SOAWTMS12A8AE47E74',
#  'SORHFEZ12AB0180E35',
#  'SOLCOAG12A8C13D8B1',
#  'SOGIRLD12A6701C5F9',
#  'SOUABCO12AB018428E',
#  'SOFUWES12AB0188316',
#  'SOSZUFD12A8C1369D1',
#  ...]

# %%
# TEST CODE

# triplets.head(120)['user_id'].nunique()
gb = triplets.head(5).groupby('user_id')
def yolo(vals):
    print(vals)
    return len(vals)
def polo(vals):
#     print(vals)
    return [len(vals), 1]

df = gb.agg([yolo, polo])
df.columns = df.columns.droplevel(0)
df = df.reset_index()
# df.columns
df.head()
