# %% [markdown]
# # Metadata Diversity
#
# Given a list of track_id's, the metadata diversity of the list is:
#
# List_Diversity = (A)num_genres + (B)num_albums + (C)num_artists + (D)num_decades + ...
# Where A,B,C,D,... are positive constants

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('song_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                           artist_mbid             artist_name  \
# 0           0  c43bb0d6-94d7-410f-80fb-e5a243b18d23                 Raphaël
# 1           1  a69cd724-2f57-4ed0-bfed-ba20401eb84c           Julie Zenatti
# 2           2  60bd8a1c-c093-4849-8f28-08101ca059b1   The Baltimore Consort
# 3           3  44b5b950-2ae2-403a-8c67-82d8fc72033d            I Hate Sally
# 4           4  0e6524bd-6641-46a6-bce5-96f06c19aa46  Orlando Pops Orchestra
#
#    artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 0             2676           0.0  148.74077     0.0    0    -9.636     1
# 1             5772           0.0  252.99546     0.0    1   -11.061     0
# 2            20540           0.0   78.02730     0.0    3   -24.140     1
# 3               -1           0.0  163.63057     0.0    7    -5.795     1
# 4               -1           0.0  199.99302     0.0   10   -16.477     1
#
#                                            release  release_7digitalid  \
# 0          Je Sais Que La Terre Est Plate (Deluxe)              275907
# 1                                       Comme Vous              382807
# 2  Watkins Ale -  Music of the English Renaissance              490659
# 3                                 Don't Worry Lady              116616
# 4                    Easy Listening: Cartoon Songs              767122
#
#    song_hotttnesss             song_id    tempo  time_signature  \
# 0         0.547953  SOGSMXL12A81C23D88  124.059               4
# 1         0.475638  SOMBCOW12AAF3B229F   80.084               4
# 2              NaN  SOEYIHF12AB017B5F4   54.874               4
# 3              NaN  SODJYEC12A8C13D757   77.150               3
# 4              NaN  SOGSOUE12A58A76443  120.382               4
#
#                                    title  track_7digitalid  \
# 0         Je Sais Que La Terre Est Plate           3073568
# 1                              On Efface           4249244
# 2                        Howells Delight           5436063
# 3                          Martha Served           1199928
# 4  Zip-A-Dee-Doo-Dah (Song of the South)           8493899
#
#              track_id  year
# 0  TRARRZU128F4253CA2  2008
# 1  TRARRJL128F92DED0E  2004
# 2  TRARRUZ128F9307C57     0
# 3  TRARRWA128F42A0195  2007
# 4  TRARRPG12903CD1DE9     0

# %%
df[df['track_id'].isin(['TRARRZU128F4253CA2', 'TRARRJL128F92DED0E'])].head()
# Out:
#    Unnamed: 0                           artist_mbid    artist_name  \
# 0           0  c43bb0d6-94d7-410f-80fb-e5a243b18d23        Raphaël
# 1           1  a69cd724-2f57-4ed0-bfed-ba20401eb84c  Julie Zenatti
#
#    artist_playmeid  danceability   duration  energy  key  loudness  mode  \
# 0             2676           0.0  148.74077     0.0    0    -9.636     1
# 1             5772           0.0  252.99546     0.0    1   -11.061     0
#
#                                    release  release_7digitalid  \
# 0  Je Sais Que La Terre Est Plate (Deluxe)              275907
# 1                               Comme Vous              382807
#
#    song_hotttnesss             song_id    tempo  time_signature  \
# 0         0.547953  SOGSMXL12A81C23D88  124.059               4
# 1         0.475638  SOMBCOW12AAF3B229F   80.084               4
#
#                             title  track_7digitalid            track_id  year
# 0  Je Sais Que La Terre Est Plate           3073568  TRARRZU128F4253CA2  2008
# 1                       On Efface           4249244  TRARRJL128F92DED0E  2004

# %%
np.round(df['duration']/60).nunique()
# Out:
# 0        2.0
# 1        4.0
# 2        1.0
# 3        3.0
# 4        3.0
# 5        5.0
# 6        4.0
# 7        4.0
# 8        4.0
# 9        5.0
# 10       4.0
# 11      10.0
# 12       5.0
# 13       4.0
# 14       2.0
# 15       7.0
# 16       2.0
# 17       3.0
# 18      10.0
# 19       3.0
# 20       5.0
# 21       3.0
# 22       9.0
# 23       2.0
# 24       5.0
# 25       4.0
# 26       3.0
# 27       5.0
# 28       5.0
# 29       4.0
#         ...
# 9970     3.0
# 9971     5.0
# 9972     5.0
# 9973     1.0
# 9974     3.0
# 9975     5.0
# 9976     4.0
# 9977     3.0
# 9978     4.0
# 9979     5.0
# 9980     5.0
# 9981     4.0
# 9982     3.0
# 9983     2.0
# 9984     3.0
# 9985     2.0
# 9986     1.0
# 9987     3.0
# 9988     2.0
# 9989     3.0
# 9990     5.0
# 9991     3.0
# 9992     5.0
# 9993     3.0
# 9994     2.0
# 9995     4.0
# 9996     2.0
# 9997     6.0
# 9998     4.0
# 9999    15.0
# Name: duration, Length: 10000, dtype: float64

# %%
def metadata_diversity(track_ids):
    df = pd.read_csv('song_data.csv')
    df = df[df['track_id'].isin(track_ids)]
    
    diversity = 0
    # TODO: Genres
    
    diversity += 0.5*df['release_7digitalid'].nunique() # albums
    diversity += 0.5*df['artist_name'].nunique() # artists
    diversity += 0.5*df['year'].nunique() # years
    
    diversity += 0.5*np.floor(df['year']/10).nunique() # decades
    diversity += 0.5*np.round(df['duration']/60).nunique() # durations in minutes
    diversity += 0.5*np.round(df['tempo']/10).nunique() # tempo 10s of BMP
    
    return diversity

# %%
metadata_diversity(['TRARRZU128F4253CA2', 'TRARRJL128F92DED0E'])
# Out:
# 5.5
